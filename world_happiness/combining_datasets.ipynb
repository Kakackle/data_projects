# %%
import pandas as pd

# %%
whr_2023_df = pd.read_csv("datafiles/WHR2023.csv")

# %%
whr_2023_df
# Out:
#          Country name  Ladder score  Standard error of ladder score  \
# 0             Finland         7.804                           0.036
# 1             Denmark         7.586                           0.041
# 2             Iceland         7.530                           0.049
# 3              Israel         7.473                           0.032
# 4         Netherlands         7.403                           0.029
# ..                ...           ...                             ...
# 132  Congo (Kinshasa)         3.207                           0.095
# 133          Zimbabwe         3.204                           0.061
# 134      Sierra Leone         3.138                           0.082
# 135           Lebanon         2.392                           0.044
# 136       Afghanistan         1.859                           0.033
#
#      upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 0           7.875         7.733                 10.792           0.969
# ...

# %%
whr_2023_df.columns
# Out:
# Index(['Country name', 'Ladder score', 'Standard error of ladder score',
#        'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
whr_2023_columns = ['Country name', 'Ladder score', 'Social support', 'Healthy life expectancy',
                   'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']

# %%
world_2023_df = pd.read_csv('datafiles/world-data-2023.csv')

# %%
world_2023_df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
world_2023
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %%
world_2023_columns = ['Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
       'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Co2-Emissions', 'CPI',
        'CPI Change (%)', 'Fertility Rate', 'Forested Area (%)',
       'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
       'Gross tertiary education enrollment (%)', 'Infant mortality',
        'Maternal mortality ratio', 'Physicians per thousand', 'Population',
       'Population: Labor force participation (%)', 'Tax revenue (%)',
        'Unemployment rate', 'Urban_population', 'Latitude',
       'Longitude']

# %%
regional_df = pd.read_csv('datafiles/regional20052020.csv')

# %%
regional_df_columns = ['Regional Indicator',]

# %%
business_df = pd.read_csv('datafiles/Start_a_Business_2019.csv')

# %%
business_df_columns = ['Starting a Business rank', 'Time - Men (days)', 'Time - Women (days)']

# %%
sectors_df = pd.read_csv('datafiles/world_countries_with_sectors.csv')

# %%
sectors_columns = ['Agriculture', 'Industry', 'Service']

# %%
regimes_df = pd.read_csv('datafiles/political-regime.csv')

# %%
regimes_columns = ['Political regime',]

# %%
regimes_df.Year.max()
# Out:
# 2022

# %%
latest_regimes = regimes_df[regimes_df['Year'] == 2022][['Entity', 'Political regime']]

# %%
latest_regimes.reset_index(inplace=True, drop=True)

# %%
regime_names = ['closed autocracy', 'electoral autocracy', 'electoral democracy', 'liberal democracy']

# %%
latest_regimes.replace([0,1,2,3], regime_names, inplace=True)

# %%
latest_regimes.rename(columns={'Entity': 'Country'}, inplace=True)

# %%
combined_df = whr_2023.copy()

# %%
combined_df = combined_df[['Country name', 'Ladder score', 'Standard error of ladder score',
'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]

# %%
combined_df.rename(columns = {
    'Country name': 'Country',
    'upperwhisker': 'Ladder score upper whisker',
    'lowerwhisker': 'Ladder score lower whisker',
    'Standard error of ladder score': 'Ladder score standard error',
    'Freedom to make life choices': 'Freedom',
    'Perceptions of corruption': 'Corruption perception',
    'Healthy life expectancy': 'Life expectancy'
}, inplace=True)

# %%
combined_df = combined_df.merge(latest_regimes, on='Country', how='left')

# %%
world_2023_columns = ['Country', 'Density (P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
       'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Co2-Emissions', 'CPI',
        'CPI Change (%)', 'Fertility Rate', 'Forested Area (%)',
       'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
       'Gross tertiary education enrollment (%)', 'Infant mortality',
        'Maternal mortality ratio', 'Physicians per thousand', 'Population',
       'Population: Labor force participation (%)', 'Tax revenue (%)',
        'Unemployment rate', 'Urban_population', 'Latitude',
       'Longitude']

# %%
world_2023_df.rename(columns={
    'Density\n(P/Km2)' : 'Density (P/Km2)',
}, inplace=True)

# %%
world_2023_filtered = world_2023_df[[*world_2023_columns]]

# %%
combined_df = combined_df.merge(world_2023_filtered, on='Country', how='left')

# %%
regional_df.rename(columns={'Country Name': 'Country'}, inplace=True)

# %%
regional_df.columns
# Out:
# Index(['Country', 'Regional Indicator', 'Year', 'Life Ladder',
#        'Log GDP Per Capita', 'Social Support',
#        'Healthy Life Expectancy At Birth', 'Freedom To Make Life Choices',
#        'Generosity', 'Perceptions Of Corruption', 'Positive Affect',
#        'Negative Affect', 'Confidence In National Government'],
#       dtype='object')

# %%
regional_df_filtered = regional_df[regional_df['Year'] == 2022][['Country', *regional_df_columns]]

# %%
regional_df_filtered.reset_index(inplace=True, drop=True)

# %%
combined_df = combined_df.merge(regional_df_filtered, on='Country', how='left')

# %%
# business_df_columns = ['Starting a Business rank', 'Time - Men (days)', 'Time - Women (days)']

# %%
business_df.columns
# Out:
# Index(['Location', 'Region', 'Starting a Business rank',
#        'Starting a Business score', 'Procedure – Men (number)',
#        'Time – Men (days)', 'Cost – Men (% of income per capita)',
#        'Procedure – Women (number)', 'Time – Women (days)',
#        'Cost – Women (% of income per capita)',
#        'Paid-in min. capital (% of income per capita)', 'Income Level', 'GNI'],
#       dtype='object')

# %%
business_df
# Out:
#                  Location    Region  Starting a Business rank  \
# 0             New Zealand   Oceania                         1
# 1                 Georgia      Asia                         2
# 2                  Canada  Americas                         3
# 3    Hong Kong SAR, China      Asia                         3
# 4               Singapore      Asia                         3
# ..                    ...       ...                       ...
# 186                  Chad    Africa                       131
# 187              Cambodia      Asia                       132
# 188               Somalia    Africa                       133
# 189                 Haiti  Americas                       134
# 190         Venezuela, RB  Americas                       135
#
#      Starting a Business score  Procedure – Men (number)  Time – Men (days)  \
# 0                        100.0                         1                0.5
# ...

# %%
business_df.rename(columns={
  'Location': 'Country',
  'Time – Men (days)' :'Business days Men',
  'Time – Women (days)' :'Business days Women'
}, inplace=True)

# %%
business_df_columns = ['Starting a Business rank', 'Business days Men',
                       'Business days Women']

# %%
business_df_filtered = business_df[['Country', *business_df_columns]]

# %%
combined_df = combined_df.merge(business_df_filtered, on='Country', how='left')

# %%
sectors_df.columns
# Out:
# Index(['Country', 'Code', 'Region', 'Population', 'Area', 'Pop. Density',
#        'Coastline', 'Net migration', 'Infant mortality', 'GDP', 'Literacy',
#        'Phones', 'Arable', 'Crops', 'Other', 'Climate', 'Birthrate',
#        'Deathrate', 'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
sectors_columns = ['Country', *sectors_columns, 'Literacy']
sectors_columns
# Out:
# ['Country', 'Agriculture', 'Industry', 'Service', 'Literacy']

# %%
sectors_df_filtered = sectors_df[[*sectors_columns]]

# %%
combined_df = combined_df.merge(sectors_df_filtered, on='Country', how='left')

# %%
combined_df.to_csv('datafiles/combined_df_2023.csv')
