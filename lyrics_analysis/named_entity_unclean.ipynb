# %% [markdown]
# ### Named entity recognition counting tests
#
# from:
# https://www.wisecube.ai/blog/named-entity-recognition-ner-with-python/
#
# categories list:
# https://www.kaggle.com/code/curiousprogrammer/entity-extraction-and-classification-using-spacy

# %%
import pandas as pd
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
ner_categories = ["PERSON", "NORP", "ORG", "GPE", "PRODUCT", "WORK_OF_ART", "EVENT",
                  "TIME", "MONEY", "QUANTITY", "ORDINAL", "CARDINAL", "FAC"]

# %%
df_path = "dataframes/genres/combined.csv"
df = pd.read_csv(df_path, index_col = 0)
df.head()
# Out:
#     Artist                      Song Title  \
# 0  Aaliyah          Are You That Somebody?
# 1  Aaliyah                     Enough Said
# 2  Aaliyah     At Your Best (You Are Love)
# 3  Aaliyah                        Miss You
# 4  Aaliyah  Age Ain’t Nothing But a Number
#
#                                           Full Title Release Date    Year  \
# 0  Are You That Somebody? by Aaliyah (Ft. Timbaland)   1998-05-26  1998.0
# 1                 Enough Said by Aaliyah (Ft. Drake)   2012-08-05  2012.0
# 2             At Your Best (You Are Love) by Aaliyah   1994-08-22  1994.0
# 3                                Miss You by Aaliyah   2002-11-16  2002.0
# 4          Age Ain't Nothing But a Number by Aaliyah   1994-12-06  1994.0
#
#    Month   Day  Pageviews                                                url  \
# 0    5.0  26.0     373960  https://genius.com/Aaliyah-are-you-that-somebo...
# 1    8.0   5.0     316333      https://genius.com/Aaliyah-enough-said-lyrics
# 2    8.0  22.0     285549  https://genius.com/Aaliyah-at-your-best-you-ar...
# 3   11.0  16.0     245608         https://genius.com/Aaliyah-miss-you-lyrics
# 4   12.0   6.0     207419  https://genius.com/Aaliyah-age-aint-nothing-bu...
#
#    featured_count  producer_count  writer_count  \
# 0               1               1             2
# 1               1               1             3
# 2               0               1             6
# 3               0               1             3
# 4               0               1             1
#
#                                          Song Lyrics  \
# 0  79 ContributorsTranslationsFrançaisAre You Tha...
# 1  64 ContributorsEnough Said Lyrics\n(Uh) 'Cause...
# 2  57 ContributorsAt Your Best (You Are Love) Lyr...
# 3  36 ContributorsMiss You Lyrics\nOh, hey\nYeah-...
# 4  54 ContributorsAge Ain’t Nothing But a Number ...
#
#                                         Artist Image
# 0  https://images.genius.com/3fea34947a97beb226fc...
# 1  https://images.genius.com/3fea34947a97beb226fc...
# 2  https://images.genius.com/3fea34947a97beb226fc...
# 3  https://images.genius.com/3fea34947a97beb226fc...
# 4  https://images.genius.com/3fea34947a97beb226fc...

# %% [markdown]
# #### Save Artists with their summed lyrics to a separate df file for ease of use

# %%
artists = list(df['Artist'].unique())

# %%
all_lyrics_df = pd.DataFrame(columns = ['Artist', 'all_lyrics', 'genre', 'gender'])

for artist in artists:
    artist_df = df[df['Artist'] == artist]
    artist_lyrics = ' '.join(artist_df['Song Lyrics'].str.strip())
    artist_df = artist_df.reset_index()
    # print(artist_df.index)
    # genre = artist_df['genre'][0]
    # gender = artist_df['gender'][0]

    new_row = {
        'Artist': artist,
        'all_lyrics': artist_lyrics,
        # 'genre': genre,
        # 'gender': gender
    }

    new_row_df = pd.DataFrame([new_row])
    all_lyrics_df = pd.concat([all_lyrics_df, new_row_df])

# %%
all_lyrics_df.reset_index(inplace=True, drop=True)

# %%
all_lyrics_df.to_csv('dataframes/lyrics_combined_unclean.csv')

# %%
clean_lyrics_df = pd.read_csv('dataframes/lyrics_combined.csv', index_col=0)

# %%
# clean_lyrics_df.reset_index(inplace=True, drop=True)

# %%
# clean_lyrics_df.to_csv('dataframes/lyrics_combined.csv')

# %%
# clean_lyrics_df['genre']

# %%
all_lyrics_df['genre'] = clean_lyrics_df['genre']
all_lyrics_df['gender'] = clean_lyrics_df['gender']

# %%
all_lyrics_df.to_csv('dataframes/lyrics_combined_unclean.csv')

# %%
# test = df['Song Lyrics']

# %%
# test.str.strip()

# %%
test_text = all_lyrics_df['all_lyrics'][0]
print(test_text[:250])
# Out:
# 79 ContributorsTranslationsFrançaisAre You That Somebody? Lyrics
# Dirty South, can y'all really feel me?
# East Coast, feel me, West Coast, feel me
# Dirty South, can y'all really feel me?
# East Coast, feel me, West Coast, feel me
# Dirty South, can y'all re

# %%
test_doc = nlp(test_text)

# %%
entities = []
for ent in test_doc.ents:
    if ent.label_ in ner_categories:
        entities.append((ent.text, ent.label_))

# %%
for entity, category in entities:
    print(f"{entity}: {category}")
# Out:
# 79: CARDINAL
# one: CARDINAL
# Timbaland: GPE
# Japan: GPE
# Aaliyah: GPE
# Makin: PERSON
# 64: CARDINAL
# ContributorsEnough: ORG
# Baby: PRODUCT
# Manchester: GPE
# Balotelli: PERSON
# 150: CARDINAL
# 150: CARDINAL
# Yo: ORG
# 57: CARDINAL
# Haah: GPE
# 36: CARDINAL
# Said: PERSON
# Said: PERSON
# Said: PERSON
# Said: PERSON
# Said: PERSON
# Said: PERSON
# Said: PERSON
# 54: CARDINAL
# Aaliyah: GPE
# Throwin: PERSON
# Throwin: PERSON
# Throwin: PERSON
# Throwin: PERSON
# tonight: TIME
# Throwin: PERSON
# Throwin: PERSON
# Baby: PRODUCT
# Aaliyah: GPE
# Throwin: PERSON
# Throwin: PERSON
# Throwin: PERSON
# Throwin: PERSON
# Throwin: PERSON
# Throwin: PERSON
# 43: CARDINAL
# ContributorsOne: FAC
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# one: CARDINAL
# a million: CARDINAL
# feelin: GPE
# one: CARDINAL
# a million: CARDINAL
# feelin: GPE
# Need: ORG
# one: CARDINAL
# a million: CARDINAL
# feelin: GPE
# one: CARDINAL
# a million: CARDINAL
# feelin: GPE
# Anything: GPE
# one: CARDINAL
# a million: CARDINAL
# feelin: GPE
# one: CARDINAL
# a million: CARDINAL
# feelin: GPE
# one: CARDINAL
# a million: CARDINAL
# feelin: GPE
# one: CARDINAL
# a million: CARDINAL
# feelin: GPE
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# Love: WORK_OF_ART
# 66: CARDINAL
# Baby: PRODUCT
# Ooh: PERSON
# Baby: PRODUCT
# 51: CARDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# first: ORDINAL
# One: CARDINAL
# 44: CARDINAL
# Cupid: ORG
# Pillows: PERSON
# Chase: ORG
# Mornin: PERSON
# Constant: PERSON
# Secrets: ORG
# Keeps: ORG
# Bonnie: PERSON
# Clyde: GPE
# 22: CARDINAL
# Wanna Lyrics
# Ooh: PERSON
# every single night: TIME
# Said: PERSON
# Said: PERSON
# Said: PERSON
# Said: PERSON
# Said: PERSON
# 39: CARDINAL
# ContributorsBack & Forth Lyrics: ORG
# Pick: PERSON
# Tonight: TIME
# DJ: PERSON
# Ripping: WORK_OF_ART
# the Soul Train
#
# : ORG
# DJ: PERSON
# all night: TIME
# DJ: PERSON
# 26: CARDINAL
# 4: CARDINAL
# Baby: PRODUCT
# Comfort: PERSON
# Comfort: PERSON
# Comfort: PERSON
# Comfort: PERSON
# Wanna: PERSON
# Love: WORK_OF_ART
# Comfort: PERSON
# you?13Embed: PERSON
# 36: CARDINAL
# Page Letter Lyrics: ORG
# one: CARDINAL
# four: CARDINAL
# four: CARDINAL
# four: CARDINAL
# four: CARDINAL
# tonight: TIME
# tonight: TIME
# four: CARDINAL
# four: CARDINAL
# 25: CARDINAL
# ContributorsCome: ORG
# two: CARDINAL
# Callin: PERSON
# Awake: PERSON
# Tonight: TIME
# Tonight: TIME
# a minute: TIME
# Said: PERSON
# Tonight: TIME
# Tonight: TIME
# Tonight: TIME
# Tonight: TIME
# 40: CARDINAL
# ContributorsWe Need: ORG
# Ficky-ficky-ficky-ficky: FAC
# last night: TIME
# four in the morning: TIME
# Eyy: PERSON
# 22: CARDINAL
# ContributorsTalk Is Cheap Lyrics
# Yeah: WORK_OF_ART
# Suppose: PERSON
# Suppose: PERSON
# 40: CARDINAL
# Lover-Lover-Man: PERSON
# Suppose: PERSON
