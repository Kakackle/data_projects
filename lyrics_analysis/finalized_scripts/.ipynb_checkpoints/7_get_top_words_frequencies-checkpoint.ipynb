# %% [markdown]
# ### Find word frequencies for artists
# using wordlcloud
# but also saving for future reference
#
# just go through the script, but change **df_path** - path to the combined df file

# %%
import wordcloud
from wordcloud import WordCloud, STOPWORDS

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Add extra words to remove, that dont seem too interesting / appear in too many results

# %%
extra_words = ['dont', 'im', 'know', 'yeah', 'oh', 'youre',
               'ive', 'ah', 'now', 'cause', 'cant', 'thats',
              'let',]
stopwords_extra = STOPWORDS.update(extra_words)

# %%
# df_path = '../dataframes/genres/cleaned_combined.csv'
df_path = '../decade_dataframes/cleaned_df.csv'

# %%
# import os
# os.getcwd()
# os.chdir('finalized_scripts')

# %%
df = pd.read_csv(df_path, index_col = 0)

# %%
df.head().columns
# Out:
# Index(['Artist', 'Song Title', 'Full Title', 'Release Date', 'Year', 'Month',
#        'Day', 'Pageviews', 'url', 'featured_count', 'producer_count',
#        'writer_count', 'Song Lyrics', 'Artist Image', 'decade'],
#       dtype='object')

# %%
artists = list(df['Artist'].unique())
len(artists)
# Out:
# 47

# %% [markdown]
# ### Get top 20 words for each artists lyrics corpus, save the words and their frequencies
# 'top_words' column for wordcloud generation
# split columns for possible deeper analysis

# %% [markdown]
# #### How many top words?

# %%
n_words = 20

# %%
words_columns = [f'word{n}' for n in range(n_words)]
counts_columns = [f'word{n}_count' for n in range(n_words)]

# %% [markdown]
# #### choose which columns you want to save alongside common word columns

# %%
# cols = ['Artist', 'genre', 'gender', f'top_words', *words_columns, *counts_columns]
cols = ['Artist', 'decade', f'top_words', *words_columns, *counts_columns]
cols
# Out:
# ['Artist',
#  'decade',
#  'top_words',
#  'word0',
#  'word1',
#  'word2',
#  'word3',
#  'word4',
#  'word5',
#  'word6',
#  'word7',
#  'word8',
#  'word9',
#  'word10',
#  'word11',
#  'word12',
#  'word13',
#  'word14',
#  'word15',
#  'word16',
#  'word17',
#  'word18',
#  'word19',
#  'word0_count',
#  'word1_count',
#  'word2_count',
#  'word3_count',
#  'word4_count',
#  'word5_count',
#  'word6_count',
#  'word7_count',
#  'word8_count',
#  'word9_count',
#  'word10_count',
#  'word11_count',
#  'word12_count',
#  'word13_count',
#  'word14_count',
#  'word15_count',
#  'word16_count',
#  'word17_count',
#  'word18_count',
#  'word19_count']

# %%
top_n_words_df = pd.DataFrame(columns = cols)

# %%
wc = WordCloud(stopwords = STOPWORDS, max_words=n_words, collocations=False)

for artist in artists:
    artist_df = df[df['Artist'] == artist]
    lyrics = ' '.join(artist_df['Song Lyrics'].str.lower())
    
    wc.generate(lyrics)
    words_fc = pd.Series(wc.words_)
    top_words = list(words_fc.index)
    top_string = ' '.join(top_words)
    top_counts = list(words_fc.values)

    artist_df.reset_index(inplace=True)
    new_row = {
        'Artist': artist,
        'decade': artist_df['decade'][0],
        'top_words': top_string
    }

    for index, word in enumerate(top_words):
        new_row[ words_columns[index] ] = word
        new_row[ counts_columns[index] ] = top_counts[index]
    
    new_row_df = pd.DataFrame([new_row])
    new_row_df.index = [artist]
    
    top_n_words_df = pd.concat([top_n_words_df, new_row_df])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17068\3092963637.py:27: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   top_n_words_df = pd.concat([top_n_words_df, new_row_df])

# %%
top_n_words_df.sample(5)
# Out:
#                     Artist decade  \
# Little Simz    Little Simz  2020s
# De La Soul      De La Soul  1980s
# Gang Starr      Gang Starr  1980s
# ​billy woods  ​billy woods  2020s
# Yasiin Bey      Yasiin Bey  1990s
#
#                                                       top_words  word0 word1  \
# Little Simz   never love got life see wanna man lalalala tim...  never  love
# De La Soul    one two man make got yo plug will time oooh sa...    one   two
# Gang Starr    got make man yo diamond wanna shit look right ...    got  make
# ​billy woods  said time might one got back black never god e...   said  time
# Yasiin Bey    got love yall black aint nigga back world say ...    got  love
#
#               word2  word3    word4  word5  word6  ... word10_count  \
# Little Simz     got   life      see  wanna    man  ...     0.487805
# De La Soul      man   make      got     yo   plug  ...     0.428571
# Gang Starr      man     yo  diamond  wanna   shit  ...     0.485294
# ​billy woods  might    one      got   back  black  ...     0.351852
# Yasiin Bey     yall  black     aint  nigga   back  ...     0.573171
#
#              word11_count word12_count word13_count word14_count word15_count  \
# Little Simz      0.463415     0.439024     0.426829     0.414634     0.402439
# De La Soul       0.428571     0.406593     0.406593     0.384615     0.384615
# Gang Starr       0.470588     0.455882     0.455882     0.455882     0.426471
# ​billy woods     0.333333     0.333333     0.296296     0.296296     0.277778
# Yasiin Bey       0.548780     0.512195     0.475610     0.463415     0.439024
#
#              word16_count word17_count word18_count word19_count
# Little Simz      0.402439     0.390244     0.329268     0.329268
# De La Soul       0.373626     0.373626     0.373626     0.362637
# Gang Starr       0.397059     0.397059     0.382353     0.382353
# ​billy woods     0.277778     0.277778     0.259259     0.259259
# Yasiin Bey       0.414634     0.414634     0.390244     0.365854
#
# [5 rows x 43 columns]

# %%
top_n_words_df.to_csv(f'../decade_dataframes/top_{n_words}_filtered_words_by_artist.csv')

# %% [markdown]
# #### Top words generation for genres

# %%
genres = list(df['genre'].unique())
len(genres)
# Out:
# 4

# %%
n_words = 20

words_columns = [f'word{n}' for n in range(n_words)]
counts_columns = [f'word{n}_count' for n in range(n_words)]

cols = [f'top_words', *words_columns, *counts_columns]
cols
# Out:
# ['top_words',
#  'word0',
#  'word1',
#  'word2',
#  'word3',
#  'word4',
#  'word5',
#  'word6',
#  'word7',
#  'word8',
#  'word9',
#  'word10',
#  'word11',
#  'word12',
#  'word13',
#  'word14',
#  'word15',
#  'word16',
#  'word17',
#  'word18',
#  'word19',
#  'word0_count',
#  'word1_count',
#  'word2_count',
#  'word3_count',
#  'word4_count',
#  'word5_count',
#  'word6_count',
#  'word7_count',
#  'word8_count',
#  'word9_count',
#  'word10_count',
#  'word11_count',
#  'word12_count',
#  'word13_count',
#  'word14_count',
#  'word15_count',
#  'word16_count',
#  'word17_count',
#  'word18_count',
#  'word19_count']

# %%
genre_top_n_words_df = pd.DataFrame(columns = cols)

# %%
wc = WordCloud(stopwords = STOPWORDS, max_words=n_words, collocations=False)

for genre in genres:
    genre_df = df[df['genre'] == genre]
    lyrics = ' '.join(genre_df['Song Lyrics'].str.lower())
    
    wc.generate(lyrics)
    words_fc = pd.Series(wc.words_)
    top_words = list(words_fc.index)
    top_string = ' '.join(top_words)
    top_counts = list(words_fc.values)

    genre_df.reset_index(inplace=True)
    new_row = {
        'top_words': top_string
    }

    for index, word in enumerate(top_words):
        new_row[ words_columns[index] ] = word
        new_row[ counts_columns[index] ] = top_counts[index]
    
    new_row_df = pd.DataFrame([new_row])
    new_row_df.index = [genre]
    
    genre_top_n_words_df = pd.concat([genre_top_n_words_df, new_row_df])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13616\579480197.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   genre_top_n_words_df = pd.concat([genre_top_n_words_df, new_row_df])

# %%
genre_top_n_words_df
# Out:
#                                               top_words  word0  word1 word2  \
# pop   love got baby wanna go want time come make one...   love    got  baby
# rock  love might time way come one never got want il...   love  might  time
# rap   nigga got aint one go shit love back see fuck ...  nigga    got  aint
# soul  love baby got come day might time right make s...   love   baby   got
#
#       word3 word4  word5  word6  word7 word8  ... word10_count word11_count  \
# pop   wanna    go   want   time   come  make  ...     0.378378     0.378378
# rock    way  come    one  never    got  want  ...     0.598326     0.594142
# rap     one    go   shit   love   back   see  ...     0.371365     0.363535
# soul   come   day  might   time  right  make  ...     0.229404     0.223067
#
#      word12_count word13_count word14_count word15_count word16_count  \
# pop      0.350064     0.342342     0.337194     0.330759     0.321750
# rock     0.589958     0.585774     0.577406     0.560669     0.539749
# rap      0.352349     0.348993     0.338926     0.327740     0.326622
# soul     0.220532     0.212928     0.198986     0.196451     0.195184
#
#      word17_count word18_count word19_count
# pop      0.307593     0.299871     0.296010
# rock     0.523013     0.510460     0.472803
# rap      0.322148     0.319911     0.308725
# soul     0.190114     0.190114     0.188847
#
# [4 rows x 41 columns]

# %%
genre_top_n_words_df.to_csv(f'../dataframes/top_{n_words}_filtered_words_by_genre.csv')

# %% [markdown]
# ### for decades

# %%
genres = list(df['decade'].unique())
# len(genres)


n_words = 20

words_columns = [f'word{n}' for n in range(n_words)]
counts_columns = [f'word{n}_count' for n in range(n_words)]

cols = [f'top_words', *words_columns, *counts_columns]
cols


genre_top_n_words_df = pd.DataFrame(columns = cols)


wc = WordCloud(stopwords = STOPWORDS, max_words=n_words, collocations=False)

for genre in genres:
    genre_df = df[df['decade'] == genre]
    lyrics = ' '.join(genre_df['Song Lyrics'].str.lower())
    
    wc.generate(lyrics)
    words_fc = pd.Series(wc.words_)
    top_words = list(words_fc.index)
    top_string = ' '.join(top_words)
    top_counts = list(words_fc.values)

    genre_df.reset_index(inplace=True)
    new_row = {
        'top_words': top_string
    }

    for index, word in enumerate(top_words):
        new_row[ words_columns[index] ] = word
        new_row[ counts_columns[index] ] = top_counts[index]
    
    new_row_df = pd.DataFrame([new_row])
    new_row_df.index = [genre]
    
    genre_top_n_words_df = pd.concat([genre_top_n_words_df, new_row_df])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\programowanie_web_etc\python_projects\data_projects\venv\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'decades'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 genres = list(df['decades'].unique())
#       2 # len(genres)
#       5 n_words = 20
#
# File ~\Desktop\programowanie_web_etc\python_projects\data_projects\venv\lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\Desktop\programowanie_web_etc\python_projects\data_projects\venv\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'decades'

# %% [markdown]
# ### Test visualizations

# %% [markdown]
# #### by genre

# %%
for index, row in enumerate(genre_top_n_words_df.sample(4).iterrows()):
    words = row[1]['top_words'].lower()

    sum_wc = WordCloud(background_color="white", stopwords=STOPWORDS, max_words=20,
              width=800, height=400, collocations=False)
    sum_wc.generate(words)

    plt.subplot(2,2, index+1)
    
    plt.imshow(sum_wc, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'{row[0]} wc')

# %% [markdown]
# #### by artist

# %%
for index, artist in enumerate(top_n_words_df.sample(4).iterrows()):
    words = artist[1]['top_words'].lower()
    
    sum_wc = WordCloud(background_color="white", stopwords=STOPWORDS, max_words=20,
              width=800, height=400, collocations=False)
    sum_wc.generate(words)

    plt.subplot(2,2, index+1)
    
    plt.imshow(sum_wc, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'{artist[1]["Artist"]} wc')

# %% [markdown]
# ### =========== tests =============

# %%
test_df = df[df['Artist'] == 'Nas']

# %%
test_df.head()
# Out:
#     Artist          Song Title                      Full Title Release Date  \
# 560    Nas  N.Y. State of Mind       N.Y. State of Mind by Nas   1994-04-19
# 561    Nas               Ether                    Ether by Nas   2001-12-04
# 562    Nas      Life’s a Bitch  Life's a Bitch by Nas (Ft. AZ)   1994-04-19
# 563    Nas  The World Is Yours       The World Is Yours by Nas   1994-05-31
# 564    Nas         The Message              The Message by Nas   1996-07-02
#
#        Year  Month   Day  Pageviews  \
# 560  1994.0    4.0  19.0    2130085
# 561  2001.0   12.0   4.0    1706821
# 562  1994.0    4.0  19.0    1315420
# 563  1994.0    5.0  31.0    1110123
# 564  1996.0    7.0   2.0     749005
#
#                                                   url  featured_count  \
# 560    https://genius.com/Nas-ny-state-of-mind-lyrics               0
# 561               https://genius.com/Nas-ether-lyrics               0
# 562       https://genius.com/Nas-lifes-a-bitch-lyrics               1
# 563  https://genius.com/Nas-the-world-is-yours-lyrics               0
# 564         https://genius.com/Nas-the-message-lyrics               0
#
#      producer_count  writer_count  \
# 560               1             2
# 561               1             2
# 562               1             6
# 563               1             2
# 564               1             4
#
#                                            Song Lyrics  \
# 560    yeah yeah ayo black—its time word word its t...
# 561   fuck jayz whats up niggas ayo i know you aint...
# 562    ayo whats up whats up lets keep it real son ...
# 563   its yours whose world is this the world is yo...
# 564    fake thug no love you get the slug cb4 gusto...
#
#                                           Artist Image gender genre
# 560  https://images.genius.com/23061dd2dc7e863127db...   male   rap
# 561  https://images.genius.com/23061dd2dc7e863127db...   male   rap
# 562  https://images.genius.com/23061dd2dc7e863127db...   male   rap
# 563  https://images.genius.com/23061dd2dc7e863127db...   male   rap
# 564  https://images.genius.com/23061dd2dc7e863127db...   male   rap

# %%
lyrics = ' '.join(test_df['Song Lyrics'].str.lower())

# %%
wc = WordCloud(stopwords = STOPWORDS, max_words=15, collocations=False)

# %%
wc.generate(lyrics)
words_fc = pd.Series(wc.words_)
top_words = list(words_fc.index)
top_string = ' '.join(top_words)
top_counts = list(words_fc.values)

# %%
top_counts
# Out:
# [1.0,
#  0.8306451612903226,
#  0.7016129032258065,
#  0.6854838709677419,
#  0.5483870967741935,
#  0.43548387096774194,
#  0.4274193548387097,
#  0.41935483870967744,
#  0.4112903225806452,
#  0.3951612903225806,
#  0.3790322580645161,
#  0.3790322580645161,
#  0.3709677419354839,
#  0.3548387096774194,
#  0.3467741935483871]
