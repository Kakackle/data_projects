# %% [markdown]
# ## Add extra metadata to saved dataframe files

# %% [markdown]
# #### Currently:
# * adds extra gender data as column
# * adds extra genre data as column
#
# if you want to use different data, you will have to specify a different list of artists
# and create a new respective column in the df
#
# by creating new columns 'gender' and 'genre' or replacing existing ones
# * **warning**: requires a specific list of artists that belong to genre / gender, because the scripts works by comparing artist names in the dataset with those lists

# %%
import pandas as pd
import re
import os

# %% [markdown]
# ### Add artist gender data

# %%
male_artists = [
    'jayz', 'kendrick lamar', 'mf doom', 'kanye west',
    'eminem', '2pac', 'ice cube', 'nas', 'a tribe called quest', 'mos def',

    'queens of the stone age', 'nirvana', 'foo fighters', 'the strokes',
    'the white stripes', 'led zeppelin', 'fugazi', 'the rolling stones',
    'black sabbath', 'deep purple',

    'michael jackson',

    'stevie wonder', 'marvin gaye', 'curtis mayfield', 'otis redding',
    'al green', 'sam cooke', 'clarence carter'
]

female_artists = [
    'taylor swift', 'dua lipa', 'carly rae jepsen', 'madonna', 'charli xcx',
    'olivia rodrigo', 'beyoncé', 'aaliyah', 'britney spears',

    'aretha franklin', 'nina simone', 'minnie riperton'
]

# %% [markdown]
# ### decades - by looking at names in respective decade dataframes

# %%
dfs_path = '../decade_dataframes/decades/'

# %%
df_80s = pd.read_csv(dfs_path + 'rap_1980s_combined_10.csv')
df_90s = pd.read_csv(dfs_path + 'rap_1990s_combined_9.csv')
df_00s = pd.read_csv(dfs_path + 'rap_2000s_combined_10.csv')
df_10s = pd.read_csv(dfs_path + 'rap_2010s_combined_9.csv')
df_20s = pd.read_csv(dfs_path + 'rap_2020s_combined_10.csv')

# %%
d_1980s = list(df_80s['Artist'].unique())
d_1990s = list(df_90s['Artist'].unique())
d_2000s = list(df_00s['Artist'].unique())
d_2010s = list(df_10s['Artist'].unique())
d_2020s = list(df_20s['Artist'].unique())

# %%
decade_lists = [
    d_1980s,
    d_1990s,
    d_2000s,
    d_2010s,
    d_2020s,
]
decade_names = [
    '1980s',
    '1990s',
    '2000s',
    '2010s',
    '2020s',
]

# %%
def add_decade(df):
    """
    adds decade column to supplied df, returns df with new column
    """
    df['decade'] = '1980s'
    for i in df.index:
        for decade_i, decade_list in enumerate(decade_lists):
            if df['Artist'][i] in decade_list:
                df['decade'][i] = decade_names[decade_i]
    return df

# %%
### singular df file
df_path = '../decade_dataframes/artist_groupby_sum.csv'
decade_df = pd.read_csv(df_path)
# decade_df = pd.read_csv('../decade_dataframes/decades_counts.csv', index_col=0)
# for this file too
# decade_df = pd.read_csv('../decade_dataframes/cleaned_df.csv', index_col=0)

# %%
decade_df = add_decade(decade_df)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15344\2036299354.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['decade'][i] = decade_names[decade_i]
# C:\Users\User\AppData\Local\Temp\ipykernel_15344\2036299354.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['decade'][i] = decade_names[decade_i]
# C:\Users\User\AppData\Local\Temp\ipykernel_15344\2036299354.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
decade_df.sample(5)[['Artist', 'decade']]
# Out:
#             Artist decade
# 10    Deltron 3030  2000s
# 37  Run The Jewels  2010s
# 31           N.W.A  1980s
# 27       Lil Wayne  2000s
# 20           JAY-Z  2000s

# %% [markdown]
# ## Watch out for overwriting files!!!!

# %%
# decade_df.to_csv('../decade_dataframes/cleaned_df.csv')
decade_df.to_csv(df_path)

# %%
def add_gender(df):
    """
    adds genre column to supllied df, returns df with new column
    """
    df['gender'] = 'male'
    for i in df.index:
        if df['Artist'][i].lower() in male_artists:
            df['gender'][i] = 'male'
        if df['Artist'][i].lower() in female_artists:
            df['gender'][i] = 'female'
    return df

# %%
os.getcwd()
# dataframes/group_stats/sum/combined_artists.csv
# Out:
# 'C:\\Users\\User\\Desktop\\programowanie_web_etc\\python_projects\\data_projects\\lyrics_analysis\\finalized_scripts'

# %%
# dataframe_path = '../dataframes/genres'
df_paths = [
    '../dataframes/group_stats/sum/combined_artists.csv',
    '../dataframes/group_stats/mean/combined_artists.csv'
]

dfs = []

for path in df_paths:
    df = pd.read_csv(path, index_col=0)
    dfs.append(df)

# %%
# for genre in ['pop', 'rock', 'rap', 'soul']:
#     df_path = f'{dataframe_path}/cleaned_{genre}_10.csv'

#     df = pd.read_csv(df_path, index_col = 0)

#     df = add_gender(df)
#     df.to_csv(df_path)

# %%
for index, df in enumerate(dfs):
    df = add_gender(df)
    df.to_csv(df_paths[index])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11700\69828769.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'][i] = 'female'
# C:\Users\User\AppData\Local\Temp\ipykernel_11700\69828769.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'][i] = 'female'
# C:\Users\User\AppData\Local\Temp\ipykernel_11700\69828769.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'][i] = 'female'
# ...

# %% [markdown]
# ### Add extra genre data

# %%
rap_artists = [
    'jayz',
    'kendrick lamar',
    'mf doom',
    'kanye west',
    'eminem',
    '2pac',
    'ice cube',
    'nas',
    'a tribe called quest',
    'mos def'
]

rock_artists = [
    'queens of the stone age',
    'nirvana',
    'foo fighters',
    'the strokes',
    'the white stripes',
    'led zeppelin',
    'fugazi',
    'the rolling stones',
    'black sabbath',
    'deep purple'
]

pop_artists = [
    'taylor swift',
    'dua lipa',
    'carly rae jepsen',
    'madonna',
    'michael jackson',
    'charli xcx',
    'olivia rodrigo',
    'beyoncé',
    'aaliyah',
    'britney spears'
]

soul_artists = [
    'stevie wonder',
    'marvin gaye',
    'curtis mayfield',
    'otis redding',
    'aretha franklin',
    'al green',
    'nina simone',
    'sam cooke',
    'clarence carter',
    'minnie riperton'
]

# %%
def add_genre(df):
    df['genre'] = 'rap'
    for i in df.index:
        if df['Artist'][i].lower() in rap_artists:
            df['genre'][i] = 'rap'
        if df['Artist'][i].lower() in rock_artists:
            df['genre'][i] = 'rock'
        if df['Artist'][i].lower() in pop_artists:
            df['genre'][i] = 'pop'
        if df['Artist'][i].lower() in soul_artists:
            df['genre'][i] = 'soul'
    return df

# %%
# for genre in ['pop', 'rock', 'rap', 'soul']:
#     df_path = f'{dataframe_path}/cleaned_{genre}_10.csv'

#     df = pd.read_csv(df_path, index_col = 0)

#     df = add_genre(df)
#     df.to_csv(df_path)

# %%
for index, df in enumerate(dfs):
    df = add_genre(df)
    df.to_csv(df_paths[index])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11700\1958485017.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genre'][i] = 'pop'
# C:\Users\User\AppData\Local\Temp\ipykernel_11700\1958485017.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genre'][i] = 'pop'
# C:\Users\User\AppData\Local\Temp\ipykernel_11700\1958485017.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genre'][i] = 'pop'
# ...
