# %%
import pandas as pd
import plotly.express as px
from nltk import FreqDist
import spacy

# %%
# Load the language model
nlp = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv('dataframes/lyrics_combined.csv', index_col = 0)

# %%
df.head()
# Out:
#              Artist                                         all_lyrics genre  \
# 0           Aaliyah   dirty south can yall really feel me east coas...   pop
# 1           Beyoncé   ive been drinkin ive been drinkin i get filth...   pop
# 2    Britney Spears   oh baby baby oh baby baby  oh baby baby how w...   pop
# 3  Carly Rae Jepsen   i threw a wish in the well dont ask me ill ne...   pop
# 4        Charli XCX   i was busy thinkin bout boys boys boys always...   pop
#
#    gender
# 0  female
# 1  female
# 2  female
# 3  female
# 4  female

# %%
test_data = df.loc[0, 'all_lyrics'].strip()

# %%
doc = nlp(test_data)

# %%
filtered_data = [token.text for token in doc if not token.is_stop]
# remove one-letter errors
filtered_data = [token for token in filtered_data if len(token)>1]

# %%
test_freq = FreqDist(filtered_data)

# %%
test_freq
# Out:
# FreqDist({'nt': 208, 'let': 113, 'baby': 96, 'know': 89, 'love': 82, 'wanna': 77, 'come': 73, 'yeah': 64, 'forth': 63, 'oh': 61, ...})

# %%
test_freq.items()
# Out:
# dict_items([('dirty', 4), ('south', 4), ('feel', 42), ('east', 4), ('coast', 11), ('west', 4), ('boy', 23), ('ve', 16), ('watching', 1), ('like', 44), ('hawk', 1), ('sky', 1), ('flies', 1), ('prey', 2), ('promise', 10), ('bumpin', 1), ('heads', 1), ('know', 89), ('days', 3), ('gon', 16), ('hook', 1), ('prolly', 1), ('talk', 28), ('phone', 9), ('nt', 208), ('good', 11), ('holdin', 1), ('secret', 1), ('probably', 14), ('tell', 52), ('let', 113), ('talkin', 4), ('bout', 7), ('responsible', 4), ('got', 51), ('ta', 26), ('watch', 7), ('cause', 44), ('anybody', 4), ('goodygoody', 5), ('right', 10), ('naughtynaughty', 4), ('yes', 10), ('need', 38), ('somebody', 17), ('wo', 14), ('pick', 3), ('park', 1), ('block', 1), ('sleep', 9), ('ill', 33), ('waiting', 1), ('trench', 1), ('locs', 1), ('hat', 1), ('lowkey', 1), ('world', 9), ('speak', 4), ('weak', 2), ('oh', 61), ('trusting', 1), ('heart', 25), ('soul', 5), ('hope', 2), ('baby', 96), ('girl', 30), ('man', 4), ('big', 2), ('va', 1), ('come', 73), ('play', 4), ('round', 1), ('way', 8), ('listen', 1), ('timbaland', 2), ('rock', 29), ('shows', 1), ('japan', 1), ('people', 2), ('shaking', 2), ('hand', 6), ('better', 14), ('known', 1), ('aaliyah', 2), ('goosebumps', 1), ('high', 3), ('fevers', 1), ('makin', 1), ('playa', 1), ('haters', 1), ('believers', 1), ('dontcha', 1), ('naughty', 2), ('uh', 11), ('ready', 8), ('ooh', 21), ('yeahyeahyeahyeahyeahyeahyeah', 12), ('yo', 11), ('wrong', 6), ('wanna', 77), ('lot', 1), ('mind', 6), ('sit', 3), ('lets', 8), ('hate', 1), ('babe', 2), ('hey', 24), ('little', 3), ('long', 26), ('help', 5), ('want', 19), ('went', 6), ('nigga', 3), ('serving', 1), ('tele', 1), ('venues', 1), ('manchester', 1), ('swerving', 1), ('balotelli', 1), ('fuck', 3), ('trying', 1), ('bothers', 1), ('therapist', 1), ('shits', 1), ('embarrassing', 1), ('bring', 5), ('niggas', 3), ('comparison', 1), ('forgive', 1), ('150', 2), ('ai', 44), ('time', 28), ('bitch', 5), ('acting', 1), ('iffy', 1), ('running', 1), ('city', 2), ('kidney', 1), ('selling', 1), ('kidding', 1), ('discussion', 1), ('wake', 1), ('disgusted', 1), ('million', 9), ('gain', 2), ('enemy', 1), ('cousin', 1), ('peoples', 1), ('feelings', 1), ('changed', 1), ('girls', 2), ('ladies', 1), ('friends', 5), ('having', 1), ('babies', 2), ('dropping', 1), ('dead', 1), ('shit', 10), ('crazy', 3), ('speaking', 1), ('helps', 1), ('love', 82), ('doubt', 2), ('shut', 1), ('loves', 1), ('yeah', 64), ('came', 3), ('far', 2), ('try', 43), ('haah', 1), ('haaaah', 1), ('hard', 2), ('mood', 2), ('learn', 1), ('think', 11), ('times', 2), ('find', 4), ('strength', 1), ('mirror', 1), ('best', 4), ('positive', 3), ('motivating', 3), ('force', 3), ('life', 7), ('wonder', 3), ('understand', 11), ('things', 5), ('taken', 1), ('place', 4), ('affair', 1), ('began', 1), ('confusion', 4), ('fall', 4), ('short', 1), ('believe', 6), ('look', 3), ('stay', 7), ('yeahyeahyeah', 2), ('nononononono', 1), ('lost', 9), ('na', 12), ('said', 23), ('needing', 8), ('wanting', 7), ('wondering', 10), ('cry', 8), ('miss', 10), ('college', 1), ('away', 10), ('straight', 1), ('school', 4), ('left', 13), ('close', 2), ('lovers', 1), ('gone', 10), ('live', 28), ('calling', 7), ('hear', 4), ('sitting', 1), ('thinking', 2), ('share', 4), ('driving', 1), ('care', 12), ('killing', 1), ('concentrate', 1), ('iiiiii', 2), ('iiiii', 2), ('talking', 1), ('thing', 30), ('fifth', 1), ('1993', 1), ('aaliyahs', 2), ('diary', 1), ('age', 17), ('nothin', 32), ('number', 16), ('throwin', 12), ('lovin', 13), ('ll', 21), ('change', 42), ('eyes', 3), ('callin', 4), ('knock', 1), ('passion', 2), ('flows', 1), ('mean', 6), ('bold', 3), ('true', 5), ('ecstasy', 1), ('brave', 1), ('afraid', 1), ('tonight', 10), ('reach', 2), ('meant', 1), ('chemistry', 2), ('replaced', 1), ('spend', 3), ('goes', 8), ('feelin', 8), ('day', 9), ('turn', 23), ('inside', 2), ('personality', 3), ('makes', 1), ('smile', 1), ('style', 1), ('fly', 1), ('deny', 1), ('crush', 1), ('diggin', 1), ('desires', 2) ...

# %%
def generate_freq_dist(row):
    lyrics = row['all_lyrics'].strip()
    doc = nlp(lyrics)
    filtered_data = [token.text for token in doc if not token.is_stop]
    # remove one-letter errors
    filtered_data = [token for token in filtered_data if len(token)>1]
    freq_dist = FreqDist(filtered_data)
    return freq_dist

# %%
def apply_generate_freq_dist(df):
    df['freq_dist'] = df.apply(
    lambda row: generate_freq_dist(row),
    axis = 1
    )

# %%
apply_generate_freq_dist(df)

# %%
df
# Out:
#                      Artist  \
# 0                   Aaliyah
# 1                   Beyoncé
# 2            Britney Spears
# 3          Carly Rae Jepsen
# 4                Charli XCX
# 5                  Dua Lipa
# 6                   Madonna
# 7           Michael Jackson
# 8            Olivia Rodrigo
# 9              Taylor Swift
# 10                     2Pac
# 11     A Tribe Called Quest
# 12                   Eminem
# 13                 Ice Cube
# 14                    JAY-Z
# 15               Kanye West
# 16           Kendrick Lamar
# 17                  MF DOOM
# 18                      Nas
# 19               Yasiin Bey
# 20            Black Sabbath
# 21              Deep Purple
# 22             Foo Fighters
# 23                   Fugazi
# 24             Led Zeppelin
# 25                  Nirvana
# 26  Queens of the Stone Age
# 27       The Rolling Stones
# 28              The Strokes
# 29        The White Stripes
# 30                 Al Green
# 31          Aretha Franklin
# 32          Clarence Carter
# 33          Curtis Mayfield
# 34              Marvin Gaye
# 35          Minnie Riperton
# 36              Nina Simone
# 37             Otis Redding
# 38                Sam Cooke
# 39            Stevie Wonder
#
#                                            all_lyrics genre  gender  \
# 0    dirty south can yall really feel me east coas...   pop  female
# 1    ive been drinkin ive been drinkin i get filth...   pop  female
# 2    oh baby baby oh baby baby  oh baby baby how w...   pop  female
# 3    i threw a wish in the well dont ask me ill ne...   pop  female
# 4    i was busy thinkin bout boys boys boys always...   pop  female
# 5    one  talkin in my sleep at night makin myself...   pop  female
# 6    life is a mystery everyone must stand alone i...   pop  female
# 7    she was more like a beauty queen from a movie...   pop    male
# 8    i got my drivers license last week just like ...   pop  female
# 9    i walked through the door with you the air wa...   pop  female
# 10   suckaass i aint got no mothafuckin friends th...  rock    male
# 11    relax yourself girl please settle down relax...  rock    male
# 12   comin at you at supersonic speed jj fad uh su...  rock    male
# 13   damn forgot to do somethin let me see uh oh y...  rock    male
# 14   youd take the clothes off my back and id let ...  rock    male
# 15   well it is a weepin and a moanin and a gnashi...  rock    male
# 16   nobody pray for me it been that day for me wa...  rock    male
# 17   mic check when i was led to you i knew you we...  rock    male
# 18    yeah yeah ayo black—its time word word its t...  rock    male
# 19    buckabuckabuckabuckabuckabucka haha you know...  rock    male
# 20    finished with my woman cause she couldnt hel...   rap    male
# 21    we all came out to montreux on the lake gene...   rap    male
# 22   hello ive waited here for you everlong tonigh...   rap    male
# 23   out here barely see my breath surrounded by j...   rap    male
# 24    theres a lady whos sure all that glitters is...   rap    male
# 25   load up on guns bring your friends its fun to...   rap    male
# 26   we get some rules to follow that and this the...   rap    male
# 27   yeow yeow yeow  please allow me to introduce ...   rap    male
# 28   theyve been sayin youre sophisticated theyre ...   rap    male
# 29   im gonna fight em off a seven nation army cou...   rap    male
# 30   lets stay together  i im so in love with you ...  soul    male
# 31    what you want baby i got it what you need do...  soul  female
# 32  i was born and raised down in alabama on a far...  soul    male
# 33   im your mama im your daddy im that nigga in t...  soul    male
# 34   hey heyhey hey whats happenin hey brother wha...  soul    male
# 35   lovin you is easy cause youre beautiful makin...  soul  female
# 36   birds flying high you know how i feel sun in ...  soul  female
# 37   sittin in the mornin sun ill be sittin when t...  soul    male
# 38   i was born by the river in a little tent oh a...  soul    male
# 39   as around the sun the earth knows shes revolv...  soul    male
#
#                                             freq_dist
# 0   {'dirty': 4, 'south': 4, 'feel': 42, 'east': 4...
# 1   {'ve': 19, 'drinkin': 6, 'filthy': 1, 'liquor'...
# 2   {'oh': 103, 'baby': 90, 'supposed': 2, 'know':...
# 3   {'threw': 1, 'wish': 2, 'nt': 104, 'ask': 1, '...
# 4   {'busy': 10, 'thinkin': 9, 'bout': 24, 'boys':...
# 5   {'talkin': 1, 'sleep': 5, 'night': 33, 'makin'...
# 6   {'life': 13, 'mystery': 5, 'stand': 3, 'hear':...
# 7   {'like': 51, 'beauty': 1, 'queen': 1, 'movie':...
# 8   {'got': 23, 'drivers': 1, 'license': 1, 'week'...
# 9   {'walked': 4, 'door': 8, 'air': 3, 'cold': 2, ...
# 10  {'suckaass': 1, 'ai': 104, 'nt': 274, 'got': 1...
# 11  {'relax': 39, 'girl': 42, 'settle': 37, 'honey...
# 12  {'comin': 6, 'supersonic': 1, 'speed': 1, 'jj'...
# 13  {'damn': 9, 'forgot': 6, 'somethin': 1, 'let':...
# 14  {'clothes': 4, 'let': 23, 'yeah': 128, 'steal'...
# 15  {'weepin': 11, 'moanin': 9, 'gnashin': 11, 'te...
# 16  {'pray': 14, 'day': 19, 'way': 44, 'yeah': 40,...
# 17  {'mic': 13, 'check': 8, 'led': 2, 'knew': 5, '...
# 18  {'yeah': 53, 'ayo': 6, 'black': 27, 'time': 37...
# 19  {'buckabuckabuckabuckabuckabucka': 1, 'haha': ...
# 20  {'finished': 1, 'woman': 2, 'cause': 8, 'nt': ...
# 21  {'came': 6, 'montreux': 1, 'lake': 1, 'geneva'...
# 22  {'hello': 1, 've': 23, 'waited': 9, 'everlong'...
# 23  {'barely': 1, 'breath': 1, 'surrounded': 1, 'j...
# 24  {'lady': 4, 'sure': 4, 'glitters': 1, 'gold': ...
# 25  {'load': 1, 'guns': 1, 'bring': 1, 'friends': ...
# 26  {'rules': 1, 'follow': 5, 'knows': 6, 'pills':...
# 27  {'yeow': 3, 'allow': 1, 'introduce': 2, 'man':...
# 28  {'ve': 12, 'sayin': 2, 'sophisticated': 1, 'co...
# 29  {'gon': 40, 'na': 40, 'fight': 3, 'em': 6, 'se...
# 30  {'lets': 7, 'stay': 9, 'love': 107, 'want': 14...
# 31  {'want': 11, 'baby': 76, 'got': 62, 'need': 27...
# 32  {'born': 1, 'raised': 2, 'alabama': 1, 'farm':...
# 33  {'mama': 9, 'daddy': 3, 'nigga': 2, 'alley': 2...
# 34  {'hey': 21, 'heyhey': 1, 'happenin': 3, 'broth...
# 35  {'lovin': 11, 'easy': 2, 'cause': 16, 'beautif...
# 36  {'birds': 1, 'flying': 1, 'high': 2, 'know': 5...
# 37  {'sittin': 7, 'mornin': 2, 'sun': 4, 'ill': 8,...
# 38  {'born': 1, 'river': 8, 'little': 10, 'tent': ...
# 39  {'sun': 9, 'earth': 12, 'knows': 4, 'revolving...

# %%
def sort_freq_dist(row):
    freq_dist = row['freq_dist']
    sorted_dist = sorted(freq_dist.items(), key = lambda x: x[1], reverse=True)
    sorted_dist = dict(sorted_dist)
    return sorted_dist

# %%
df['sorted_dist'] = df.apply(
    lambda row: sort_freq_dist(row),
    axis = 1
)

# %%
df
# Out:
#                      Artist  \
# 0                   Aaliyah
# 1                   Beyoncé
# 2            Britney Spears
# 3          Carly Rae Jepsen
# 4                Charli XCX
# 5                  Dua Lipa
# 6                   Madonna
# 7           Michael Jackson
# 8            Olivia Rodrigo
# 9              Taylor Swift
# 10                     2Pac
# 11     A Tribe Called Quest
# 12                   Eminem
# 13                 Ice Cube
# 14                    JAY-Z
# 15               Kanye West
# 16           Kendrick Lamar
# 17                  MF DOOM
# 18                      Nas
# 19               Yasiin Bey
# 20            Black Sabbath
# 21              Deep Purple
# 22             Foo Fighters
# 23                   Fugazi
# 24             Led Zeppelin
# 25                  Nirvana
# 26  Queens of the Stone Age
# 27       The Rolling Stones
# 28              The Strokes
# 29        The White Stripes
# 30                 Al Green
# 31          Aretha Franklin
# 32          Clarence Carter
# 33          Curtis Mayfield
# 34              Marvin Gaye
# 35          Minnie Riperton
# 36              Nina Simone
# 37             Otis Redding
# 38                Sam Cooke
# 39            Stevie Wonder
#
#                                            all_lyrics genre  gender  \
# 0    dirty south can yall really feel me east coas...   pop  female
# 1    ive been drinkin ive been drinkin i get filth...   pop  female
# 2    oh baby baby oh baby baby  oh baby baby how w...   pop  female
# 3    i threw a wish in the well dont ask me ill ne...   pop  female
# 4    i was busy thinkin bout boys boys boys always...   pop  female
# 5    one  talkin in my sleep at night makin myself...   pop  female
# 6    life is a mystery everyone must stand alone i...   pop  female
# 7    she was more like a beauty queen from a movie...   pop    male
# 8    i got my drivers license last week just like ...   pop  female
# 9    i walked through the door with you the air wa...   pop  female
# 10   suckaass i aint got no mothafuckin friends th...  rock    male
# 11    relax yourself girl please settle down relax...  rock    male
# 12   comin at you at supersonic speed jj fad uh su...  rock    male
# 13   damn forgot to do somethin let me see uh oh y...  rock    male
# 14   youd take the clothes off my back and id let ...  rock    male
# 15   well it is a weepin and a moanin and a gnashi...  rock    male
# 16   nobody pray for me it been that day for me wa...  rock    male
# 17   mic check when i was led to you i knew you we...  rock    male
# 18    yeah yeah ayo black—its time word word its t...  rock    male
# 19    buckabuckabuckabuckabuckabucka haha you know...  rock    male
# 20    finished with my woman cause she couldnt hel...   rap    male
# 21    we all came out to montreux on the lake gene...   rap    male
# 22   hello ive waited here for you everlong tonigh...   rap    male
# 23   out here barely see my breath surrounded by j...   rap    male
# 24    theres a lady whos sure all that glitters is...   rap    male
# 25   load up on guns bring your friends its fun to...   rap    male
# 26   we get some rules to follow that and this the...   rap    male
# 27   yeow yeow yeow  please allow me to introduce ...   rap    male
# 28   theyve been sayin youre sophisticated theyre ...   rap    male
# 29   im gonna fight em off a seven nation army cou...   rap    male
# 30   lets stay together  i im so in love with you ...  soul    male
# 31    what you want baby i got it what you need do...  soul  female
# 32  i was born and raised down in alabama on a far...  soul    male
# 33   im your mama im your daddy im that nigga in t...  soul    male
# 34   hey heyhey hey whats happenin hey brother wha...  soul    male
# 35   lovin you is easy cause youre beautiful makin...  soul  female
# 36   birds flying high you know how i feel sun in ...  soul  female
# 37   sittin in the mornin sun ill be sittin when t...  soul    male
# 38   i was born by the river in a little tent oh a...  soul    male
# 39   as around the sun the earth knows shes revolv...  soul    male
#
#                                             freq_dist  \
# 0   {'dirty': 4, 'south': 4, 'feel': 42, 'east': 4...
# 1   {'ve': 19, 'drinkin': 6, 'filthy': 1, 'liquor'...
# 2   {'oh': 103, 'baby': 90, 'supposed': 2, 'know':...
# 3   {'threw': 1, 'wish': 2, 'nt': 104, 'ask': 1, '...
# 4   {'busy': 10, 'thinkin': 9, 'bout': 24, 'boys':...
# 5   {'talkin': 1, 'sleep': 5, 'night': 33, 'makin'...
# 6   {'life': 13, 'mystery': 5, 'stand': 3, 'hear':...
# 7   {'like': 51, 'beauty': 1, 'queen': 1, 'movie':...
# 8   {'got': 23, 'drivers': 1, 'license': 1, 'week'...
# 9   {'walked': 4, 'door': 8, 'air': 3, 'cold': 2, ...
# 10  {'suckaass': 1, 'ai': 104, 'nt': 274, 'got': 1...
# 11  {'relax': 39, 'girl': 42, 'settle': 37, 'honey...
# 12  {'comin': 6, 'supersonic': 1, 'speed': 1, 'jj'...
# 13  {'damn': 9, 'forgot': 6, 'somethin': 1, 'let':...
# 14  {'clothes': 4, 'let': 23, 'yeah': 128, 'steal'...
# 15  {'weepin': 11, 'moanin': 9, 'gnashin': 11, 'te...
# 16  {'pray': 14, 'day': 19, 'way': 44, 'yeah': 40,...
# 17  {'mic': 13, 'check': 8, 'led': 2, 'knew': 5, '...
# 18  {'yeah': 53, 'ayo': 6, 'black': 27, 'time': 37...
# 19  {'buckabuckabuckabuckabuckabucka': 1, 'haha': ...
# 20  {'finished': 1, 'woman': 2, 'cause': 8, 'nt': ...
# 21  {'came': 6, 'montreux': 1, 'lake': 1, 'geneva'...
# 22  {'hello': 1, 've': 23, 'waited': 9, 'everlong'...
# 23  {'barely': 1, 'breath': 1, 'surrounded': 1, 'j...
# 24  {'lady': 4, 'sure': 4, 'glitters': 1, 'gold': ...
# 25  {'load': 1, 'guns': 1, 'bring': 1, 'friends': ...
# 26  {'rules': 1, 'follow': 5, 'knows': 6, 'pills':...
# 27  {'yeow': 3, 'allow': 1, 'introduce': 2, 'man':...
# 28  {'ve': 12, 'sayin': 2, 'sophisticated': 1, 'co...
# 29  {'gon': 40, 'na': 40, 'fight': 3, 'em': 6, 'se...
# 30  {'lets': 7, 'stay': 9, 'love': 107, 'want': 14...
# 31  {'want': 11, 'baby': 76, 'got': 62, 'need': 27...
# 32  {'born': 1, 'raised': 2, 'alabama': 1, 'farm':...
# 33  {'mama': 9, 'daddy': 3, 'nigga': 2, 'alley': 2...
# 34  {'hey': 21, 'heyhey': 1, 'happenin': 3, 'broth...
# 35  {'lovin': 11, 'easy': 2, 'cause': 16, 'beautif...
# 36  {'birds': 1, 'flying': 1, 'high': 2, 'know': 5...
# 37  {'sittin': 7, 'mornin': 2, 'sun': 4, 'ill': 8,...
# 38  {'born': 1, 'river': 8, 'little': 10, 'tent': ...
# 39  {'sun': 9, 'earth': 12, 'knows': 4, 'revolving...
#
#                                           sorted_dist
# 0   {'nt': 208, 'let': 113, 'baby': 96, 'know': 89...
# 1   {'nt': 200, 'like': 135, 'love': 119, 'halo': ...
# 2   {'nt': 121, 'oh': 103, 'like': 91, 'baby': 90,...
# 3   {'love': 123, 'nt': 104, 'want': 95, 'gimmie':...
# 4   {'got': 239, 'like': 206, 'party': 166, 'shake...
# 5   {'nt': 232, 'know': 80, 'come': 78, 'got': 69,...
# 6   {'like': 120, 'nt': 116, 'got': 77, 've': 74, ...
# 7   {'nt': 190, 'ma': 174, 'yeah': 139, 'know': 93...
# 8   {'nt': 121, 'like': 71, 'know': 65, 'oh': 59, ...
# 9   {'nt': 107, 'like': 88, 'know': 52, 'cause': 4...
# 10  {'nt': 274, 'ai': 104, 'got': 101, 'know': 79,...
# 11  {'nt': 159, 'like': 116, 'got': 110, 'know': 7...
# 12  {'nt': 309, 'like': 162, 'cause': 102, 'got': ...
# 13  {'nt': 190, 'got': 106, 'fuck': 101, 'like': 1...
# 14  {'nt': 215, 'yeah': 128, 'nigga': 121, 'got': ...
# 15  {'nt': 182, 'got': 106, 'know': 86, 'like': 78...
# 16  {'nt': 178, 'got': 125, 'nigga': 115, 'like': ...
# 17  {'like': 170, 'nt': 91, 'doom': 47, 'got': 46,...
# 18  {'like': 144, 'nt': 141, 'nas': 87, 'love': 84...
# 19  {'nt': 157, 'like': 122, 'got': 101, 'know': 9...
# 20  {'yeah': 35, 'oh': 25, 'like': 25, 'love': 24,...
# 21  {'nt': 45, 'oh': 45, 'got': 41, 'yeah': 39, 'l...
# 22  {'shame': 58, 'nt': 55, 'like': 53, 'best': 42...
# 23  {'like': 36, 'nt': 34, 'got': 34, 've': 33, 's...
# 24  {'oh': 142, 'baby': 70, 'love': 69, 'ah': 67, ...
# 25  {'nt': 86, 'yeah': 61, 'said': 49, 'way': 46, ...
# 26  {'ah': 62, 'nt': 48, 'like': 39, 'oh': 29, 'wa...
# 27  {'nt': 121, 'yeah': 83, 'like': 43, 'hey': 41,...
# 28  {'nt': 134, 'oh': 80, 'yeah': 49, 'like': 48, ...
# 29  {'nt': 71, 'love': 48, 'know': 45, 'gon': 40, ...
# 30  {'love': 107, 'yeah': 95, 'baby': 86, 'nt': 62...
# 31  {'nt': 113, 'oh': 93, 'love': 85, 'chain': 80,...
# 32  {'nt': 111, 'love': 83, 'got': 42, 'baby': 35,...
# 33  {'nt': 110, 'love': 52, 'world': 41, 'got': 40...
# 34  {'baby': 156, 'oh': 113, 'nt': 78, 'love': 76,...
# 35  {'na': 83, 'love': 81, 'la': 78, 'oh': 48, 'ba...
# 36  {'nt': 110, 'got': 63, 'power': 57, 'lord': 55...
# 37  {'love': 88, 'got': 70, 'nt': 66, 'oh': 53, 'v...
# 38  {'know': 85, 'day': 65, 'yeah': 64, 'oh': 53, ...
# 39  {'love': 129, 'nt': 107, 'da': 105, 'la': 68, ...

# %%
dist_1 = df.loc[0, 'sorted_dist']
dist_2 = df.loc[1, 'sorted_dist']

# %%
import math

# %%
compared = {}
for key, value in dist_1.items():
    value2 = dist_2.get(key, 0)
    if value2 == 0:
        comparison = 1000
    else:
        comparison = math.log(value / value2)
    compared[key] = comparison

# %%
compared_sorted = sorted(compared.items(), key = lambda x: x[1], reverse=True)
compared_sorted = dict(compared_sorted)

# %%
compared_sorted
# Out:
# {'forth': 1000,
#  'change': 1000,
#  'boat': 1000,
#  'check': 1000,
#  'huh': 1000,
#  'dust': 1000,
#  'supposed': 1000,
#  'somebody': 1000,
#  'age': 1000,
#  'number': 1000,
#  'probably': 1000,
#  'lover': 1000,
#  'yeahyeahyeahyeahyeahyeahyeah': 1000,
#  'throwin': 1000,
#  'position': 1000,
#  'succeed': 1000,
#  'coast': 1000,
#  'knew': 1000,
#  'wondering': 1000,
#  'gone': 1000,
#  'liyah': 1000,
#  'million': 1000,
#  'resolution': 1000,
#  'dog': 1000,
#  'needing': 1000,
#  'letter': 1000,
#  'ha': 1000,
#  'wanting': 1000,
#  'calling': 1000,
#  'dope': 1000,
#  'fool': 1000,
#  'glad': 1000,
#  'hand': 1000,
#  'went': 1000,
#  'positions': 1000,
#  'grooving': 1000,
#  'sending': 1000,
#  'page': 1000,
#  'enclosed': 1000,
#  'yah': 1000,
#  'unplug': 1000,
#  'goodygoody': 1000,
#  'soul': 1000,
#  'date': 1000,
#  'comfort': 1000,
#  'curse': 1000,
#  'bet': 1000,
#  'dirty': 1000,
#  'south': 1000,
#  'east': 1000,
#  'west': 1000,
#  'responsible': 1000,
#  'anybody': 1000,
#  'naughtynaughty': 1000,
#  'confusion': 1000,
#  'school': 1000,
#  'share': 1000,
#  'callin': 1000,
#  'going': 1000,
#  'freakyfreaky': 1000,
#  'mr': 1000,
#  'strong': 1000,
#  'needs': 1000,
#  'dogs': 1000,
#  'poison': 1000,
#  'eye': 1000,
#  'days': 1000,
#  'pick': 1000,
#  'niggas': 1000,
#  'positive': 1000,
#  'motivating': 1000,
#  'force': 1000,
#  'bold': 1000,
#  'personality': 1000,
#  'covers': 1000,
#  'gettin': 1000,
#  'die': 1000,
#  'dj': 1000,
#  'press': 1000,
#  'asleep': 1000,
#  'awake': 1000,
#  'arguin': 1000,
#  'issues': 1000,
#  'blamed': 1000,
#  'ashamed': 1000,
#  'remain': 1000,
#  'suppose': 1000,
#  'push': 1000,
#  'ones': 1000,
#  'sad': 1000,
#  'cold': 1000,
#  'heat': 1000,
#  'prey': 1000,
#  'weak': 1000,
#  'timbaland': 1000,
#  'shaking': 1000,
#  'aaliyah': 1000,
#  '150': 1000,
#  'city': 1000,
#  'gain': 1000,
#  'babies': 1000,
#  'mood': 1000,
#  'yeahyeahyeah': 1000,
#  'iiiiii': 1000,
#  'iiiii': 1000,
#  'aaliyahs': 1000,
#  'passion': 1000,
#  'chemistry': 1000,
#  'desires': 1000,
#  'hmm': 1000,
#  'serve': 1000,
#  'drift': 1000,
#  'deeper': 1000,
#  'hurry': 1000,
#  'explore': 1000,
#  'shy': 1000,
#  'whoa': 1000,
#  'mo': 1000,
#  'tempt': 1000,
#  'pillows': 1000,
#  'vowed': 1000,
#  'workin': 1000,
#  'party': 1000,
#  'groove': 1000,
#  'floor': 1000,
#  'chance': 1000,
#  'writing': 1000,
#  'mailmans': 1000,
#  'coming': 1000,
#  'touched': 1000,
#  'um': 1000,
#  'clothes': 1000,
#  'cryin': 1000,
#  'tomorrow': 1000,
#  'cool': 1000,
#  'fuckin': 1000,
#  'busy': 1000,
#  'easy': 1000,
#  'anymore': 1000,
#  'shared': 1000,
#  'run': 1000,
#  'fore': 1000,
#  'bending': 1000,
#  'law': 1000,
#  'moves': 1000,
#  'lay': 1000,
#  'nothings': 1000,
#  'given': 1000,
#  'feeling': 1000,
#  'drug': 1000,
#  'compare': 1000,
#  'drain': 1000,
#  'watching': 1000,
#  'hawk': 1000,
#  'sky': 1000,
#  'flies': 1000,
#  'bumpin': 1000,
#  'heads': 1000,
#  'hook': 1000,
#  'prolly': 1000,
#  'secret': 1000,
#  'block': 1000,
#  'waiting': 1000,
#  'trench': 1000,
#  'locs': 1000,
#  'hat': 1000,
#  'lowkey': 1000,
#  'trusting': 1000,
#  'va': 1000,
#  'shows': 1000,
#  'japan': 1000,
#  'goosebumps': 1000,
#  'fevers': 1000,
#  'playa': 1000,
#  'believers': 1000,
#  'dontcha': 1000,
#  'serving': 1000,
#  'tele': 1000,
#  'venues': 1000,
#  'manchester': 1000,
#  'swerving': 1000,
#  'balotelli': 1000,
#  'bothers': 1000,
#  'embarrassing': 1000,
#  'comparison': 1000,
#  'acting': 1000,
#  'iffy': 1000,
#  'kidney': 1000,
#  'selling': 1000,
#  'kidding': 1000,
#  'discussion': 1000,
#  'disgusted': 1000,
#  'enemy': 1000,
#  'cousin': 1000,
#  'peoples': 1000,
#  'changed': 1000,
#  'having': 1000,
#  'dropping': 1000,
#  'dead': 1000,
#  'speaking': 1000,
#  'helps': 1000,
#  'haah': 1000,
#  'haaaah': 1000,
#  'learn': 1000,
#  'affair': 1000,
#  'began': 1000,
#  'short': 1000,
#  'nononononono': 1000,
#  'college': 1000,
#  'lovers': 1000,
#  'sitting': 1000,
#  'driving': 1000,
#  'killing': 1000,
#  'concentrate': 1000,
#  'talking': 1000,
#  'fifth': 1000,
#  '1993': 1000,
#  'diary': 1000,
#  'knock': 1000,
#  'flows': 1000,
#  'brave': 1000,
#  'afraid': 1000,
#  'meant': 1000,
#  'replaced': 1000,
#  'makes': 1000,
#  'style': 1000,
#  'deny': 1000,
#  'crush': 1000,
#  'diggin': 1000,
#  'huhuh': 1000,
#  'float': 1000,
#  'tie': 1000,
#  'rope': 1000,
#  'overboard': 1000,
#  'truly': 1000,
#  'vote': 1000,
#  'overdrive': 1000,
#  'use': 1000,
#  'shore': 1000,
#  'freakyfreakyfreaky': 1000,
#  'hesitate': 1000,
#  'role': 1000,
#  'easily': 1000,
#  'eternity': 1000,
#  'chain': 1000,
#  'buggin': 1000,
#  'millennium': 1000,
#  'guess': 1000,
#  'instant': 1000,
#  'beads': 1000,
#  'cupids': 1000,
#  'shot': 1000,
#  'heartbeats': 1000,
#  'racin': 1000,
#  'exciting': 1000,
#  'highly': 1000,
#  'entirely': 1000,
#  'rates': 1000,
#  'climbin': 1000,
#  'separatin': 1000,
#  'massages': 1000,
#  'bones': 1000,
#  'closet': 1000,
#  'constant': 1000,
#  'pleasures': 1000,
#  'scale': 1000,
#  'measure': 1000,
#  'treasures': 1000,
#  'keeps': 1000,
#  'foreign': 1000,
#  'lands': 1000,
#  'bonnie': 1000,
#  'clyde': 1000,
#  'ohyeahyeah': 1000,
#  'hooked': 1000,
#  'sat': 1000,
#  'agreement': 1000,
#  'awhile': 1000,
#  'single': 1000,
#  'straighten': 1000,
#  'upside': 1000,
#  'dime': 1000,
#  'hurtin': 1000,
#  'mistakes': 1000,
#  'carry': 1000,
#  'swing': 1000,
#  'scene': 1000,
#  'funky': 1000,
#  'mellow': 1000,
#  'nows': 1000,
#  'dance': 1000,
#  'ripping': 1000,
#  'stage': 1000,
#  'jazz': 1000,
#  'mentality': 1000,
#  'beats': 1000,
#  'train': 1000,
#  'formality': 1000,
#  'nonononono': 1000,
#  'wipe': 1000,
#  'insane': 1000,
#  'bit': 1000,
#  'careful': 1000,
#  'particular': 1000,
#  'guy': 1000,
#  'decided': 1000,
#  'notice': 1000,
#  'nerve': 1000,
#  'quarter': 1000,
#  '102': 1000,
#  'figure': 1000,
#  'wide': 1000,
#  'wonderin': 1000,
#  'bags': 1000,
#  'road': 1000,
#  'batterys': 1000,
#  'wantin': 1000,
#  'fickyfickyfickyficky': 1000,
#  'catching': 1000,
#  'vibe': 1000,
#  'contagious': 1000,
#  'latest': 1000,
#  'misuse': 1000,
#  'resolve': 1000,
#  'causes': 1000,
#  'official': 1000,
#  'fell': 1000,
#  'couch': 1000,
#  'broke': 1000,
#  'instead': 1000,
#  'crept': 1000,
#  'eyy': 1000,
#  'holla': 1000,
#  'ugh': 1000,
#  'bits': 1000,
#  'pieces': 1000,
#  'blame': 1000,
#  'season': 1000,
#  'month': 1000,
#  'bleeding': 1000,
#  'snoop': 1000,
#  'video': 1000,
#  'looks': 1000,
#  'deceiving': 1000,
#  'coughin': 1000,
#  'wheezin': 1000,
#  'blamin': 1000,
#  'namin': 1000,
#  'sneakin': 1000,
#  'prayer': 1000,
#  'deacon': 1000,
#  'act': 1000,
#  'speakin': 1000,
#  'fickyficky': 1000,
#  'blames': 1000,
#  'agree': 1000,
#  'doors': 1000,
#  'rush': 1000,
#  'cheap': 1000,
#  'ask': 1000,
#  'stories': 1000,
#  'record': 1000,
#  'papi': 1000,
#  'vocals': 1000,
#  '40': 1000,
#  'boards': 1000,
#  'bored': 1000,
#  'loverloverman': 1000,
#  'free': 1000,
#  'end': 1000,
#  'plans': 1000,
#  'dude': 1000,
#  'bedroom': 1000,
#  'wearin': 1000,
#  'skill': 1000,
#  'chills': 1000,
#  'dissin': 1000,
#  'dumb': 1000,
#  'blackground': 1000,
#  'brought': 1000,
#  'pleasure': 1000,
#  'misery': 1000,
#  'greasy': 1000,
#  'ayyo': 1000,
#  'chasin': 1000,
#  'cat': 1000,
#  'pissin': 1000,
#  'tree': 1000,
#  'backyard': 1000,
#  'roam': 1000,
#  'bust': 1000,
#  'gun': 1000,
#  'clip': 1000,
#  'whip': 1000,
#  'lip': 1000,
#  'fence': 1000,
#  'convince': 1000,
#  'pup': 1000,
#  'stuck': 1000,
#  'street': 1000,
#  'nervous': 1000,
#  'barely': 1000,
#  'paws': 1000,
#  'small': 1000,
#  'ball': 1000,
#  'tags': 1000,
#  'neck': 1000,
#  'comes': 1000,
#  'till': 1000,
#  'explain': 1000,
#  'questions': 1000,
#  'lurking': 1000,
#  'ways': 1000,
#  'choice': 1000,
#  'exercise': 1000,
#  'searching': 1000,
#  'danger': 1000,
#  'sleeping': 1000,
#  'stranger': 1000,
#  'years': 1000,
#  'flushed': 1000,
#  'regrets': 1000,
#  'oohyeah': 1000,
#  'ohohooh': 1000,
#  'nothin': 3.4657359027997265,
#  'talk': 3.332204510175204,
#  'said': 3.1354942159291497,
#  'sayin': 2.70805020110221,
#  'try': 2.662587827025453,
#  'leave': 2.6390573296152584,
#  'woman': 2.4849066497880004,
#  'yo': 2.3978952727983707,
#  'step': 2.302585092994046,
#  'stroke': 2.268683541318364,
#  'live': 2.2335922215070942,
#  'phone': 2.1972245773362196,
#  'lost': 2.1972245773362196,
#  'mmm': 2.1400661634962708,
#  'write': 2.0794415416798357,
#  'shed': 2.0794415416798357,
#  'piece': 2.0794415416798357,
#  'll': 1.9459101490553132,
#  'left': 1.8718021769015913,
#  'thing': 1.791759469228055,
#  'tired': 1.791759469228055,
#  'mean': 1.791759469228055,
#  'throw': 1.791759469228055,
#  'alright': 1.791759469228055,
#  'heart': 1.6094379124341003,
#  'miss': 1.6094379124341003,
#  'help': 1.6094379124341003,
#  'friends': 1.6094379124341003,
#  'music': 1.6094379124341003,
#  'moment': 1.6094379124341003,
#  'world': 1.5040773967762742,
#  'come': 1.4000876832522264,
#  'cry': 1.3862943611198906,
#  'speak': 1.3862943611198906,
#  'best': 1.3862943611198906,
#  'place': 1.3862943611198906,
#  'moving': 1.3862943611198906,
#  'new': 1.3217558399823195,
#  'ill': 1.2992829841302609,
#  'uh': 1.2992829841302609,
#  'let': 1.2934006142271943,
#  'yes': 1.2039728043259361,
#  'middle': 1.1895840668738364,
#  'sit': 1.0986122886681098,
#  'wonder': 1.0986122886681098,
#  'buttons': 1.0986122886681098,
#  'lies': 1.0986122886681098,
#  'need': 1.072636802264849,
#  'ta': 1.0608719606852626,
#  'understand': 1.0116009116784799,
#  'ready': 0.9808292530117262,
#  'goes': 0.9808292530117262,
#  'gave': 0.9808292530117262,
#  'bring': 0.9162907318741551,
#  'told': 0.9162907318741551,
#  'worry': 0.8472978603872037,
#  'tell': 0.8157495026522776,
#  'wanna': 0.706219262127298,
#  'hey': 0.6931471805599453,
#  'better': 0.6931471805599453,
#  'tonight': 0.6931471805599453,
#  'wrong': 0.6931471805599453,
#  'believe': 0.6931471805599453,
#  'beat': 0.6931471805599453,
#  'break': 0.6931471805599453,
#  'maybe': 0.6931471805599453,
#  'late': 0.6931471805599453,
#  'real': 0.6931471805599453,
#  'hope': 0.6931471805599453,
#  'naughty': 0.6931471805599453,
#  'doubt': 0.6931471805599453,
#  'close': 0.6931471805599453,
#  'regular': 0.6931471805599453,
#  'tight': 0.6931471805599453,
#  'sugar': 0.6931471805599453,
#  'ah': 0.6931471805599453,
#  'reason': 0.6931471805599453,
#  'door': 0.6931471805599453,
#  'forever': 0.6931471805599453,
#  'breath': 0.6931471805599453,
#  'sleep': 0.5877866649021191,
#  'yeah': 0.5753641449035618,
#  'promise': 0.5108256237659907,
#  'cut': 0.5108256237659907,
#  'lovin': 0.4855078157817008,
#  'know': 0.4813031844996689,
#  'baby': 0.47000362924573563,
#  'day': 0.4054651081081644,
#  'spend': 0.4054651081081644,
#  'head': 0.4054651081081644,
#  'pain': 0.4054651081081644,
#  'happy': 0.4054651081081644,
#  'streets': 0.4054651081081644,
#  'work': 0.3894647667617233,
#  'time': 0.3364722366212129,
#  'wo': 0.3364722366212129,
#  'stay': 0.3364722366212129,
#  'feelin': 0.28768207245178085,
#  'shit': 0.22314355131420976,
#  'oh': 0.21905356606268467,
#  'got': 0.21825356602001797,
#  'long': 0.2135741002980591,
#  'ooh': 0.21130909366720696,
#  'cause': 0.12062798778861472,
#  'rock': 0.07145896398214505,
#  'turn': 0.044451762570833796,
#  'nt': 0.03922071315328133,
#  'feel': 0.0,
#  'watch': 0.0,
#  'true': 0.0,
#  'thought': 0.0,
#  'ride': 0.0,
#  'high': 0.0,
#  'came': 0.0,
#  'walk': 0.0,
#  'sexy': 0.0,
#  'fine': 0.0,
#  'sure': 0.0,
#  'dreams': 0.0,
#  'making': 0.0,
#  'holdin': 0.0,
#  'park': 0.0,
#  'lot': 0.0,
#  'hate': 0.0,
#  'therapist': 0.0,
#  'shits': 0.0,
#  'feelings': 0.0,
#  'strength': 0.0,
#  'straight': 0.0,
#  'ecstasy': 0.0,
#  'week': 0.0,
#  '  ': 0.0,
#  'freaky': 0.0,
#  'sweat': 0.0,
#  'midnight': 0.0,
#  'chase': 0.0,
#  'secrets': 0.0,
#  'ohoh': 0.0,
#  'ago': 0.0,
#  'fight': 0.0,
#  'realize': 0.0,
#  'flight': 0.0,
#  'headed': 0.0,
#  'bite': 0.0,
#  'tongue': 0.0,
#  'problem': 0.0,
#  'morning': 0.0,
#  'drink': 0.0,
#  'ring': 0.0,
#  'inspired': 0.0,
#  'conversation': 0.0,
#  'doin': 0.0,
#  'woo': 0.0,
#  'tryin': 0.0,
#  'word': 0.0,
#  'dick': 0.0,
#  'handle': 0.0,
#  'pass': 0.0,
#  'rip': 0.0,
#  'grown': 0.0,
#  'joy': 0.0,
#  'fair': 0.0,
#  'stand': 0.0,
#  'care': -0.08004270767353637,
#  'life': -0.13353139262452263,
#  've': -0.17185025692665928,
#  'want': -0.19105523676270922,
#  'boy': -0.19671029424605427,
#  'talkin': -0.2231435513142097,
#  'hear': -0.2231435513142097,
#  'ai': -0.2411620568168881,
#  'nigga': -0.2876820724517809,
#  'tears': -0.2876820724517809,
#  'na': -0.3483066942682157,
#  'gon': -0.3629054936893685,
#  'love': -0.37240424584727627,
#  'think': -0.3746934494414107,
#  'lets': -0.40546510810816444,
#  'find': -0.40546510810816444,
#  'fall': -0.40546510810816444,
#  'people': -0.40546510810816444,
#  'inside': -0.40546510810816444,
#  'low': -0.40546510810816444,
#  'open': -0.40546510810816444,
#  'stop': -0.4595323293784402,
#  'hurt': -0.4595323293784402,
#  'bitch': -0.4700036292457356,
#  'things': -0.4700036292457356,
#  'girl': -0.5108256237659907,
#  'mind': -0.5108256237659907,
#  'eat': -0.5108256237659907,
#  'wait': -0.5108256237659907,
#  'play': -0.5596157879354228,
#  'away': -0.6931471805599453,
#  'crazy': -0.6931471805599453,
#  'times': -0.6931471805599453,
#  'deal': -0.6931471805599453,
#  'em': -0.6931471805599453,
#  'bed': -0.6931471805599453,
#  'round': -0.6931471805599453,
#  'known': -0.6931471805599453,
#  'wake': -0.6931471805599453,
#  'shut': -0.6931471805599453,
#  'mirror': -0.6931471805599453,
#  'smile': -0.6931471805599453,
#  'fly': -0.6931471805599453,
#  'boys': -0.6931471805599453,
#  'perfect': -0.6931471805599453,
#  'grindin': -0.6931471805599453,
#  'mama': -0.6931471805599453,
#  'played': -0.6931471805599453,
#  'diss': -0.6931471805599453,
#  'car': -0.6931471805599453,
#  'twisted': -0.6931471805599453,
#  'smoke': -0.6931471805599453,
#  'sing': -0.6931471805599453,
#  'reckless': -0.6931471805599453,
#  'kill': -0.6931471805599453,
#  'hold': -0.8109302162163288,
#  'way': -0.916290731874155,
#  'reach': -0.916290731874155,
#  'feels': -0.916290731874155,
#  'start': -0.916290731874155,
#  'swear': -0.916290731874155,
#  'home': -0.9555114450274363,
#  'kiss': -0.9808292530117262,
#  'bout': -0.9985288301111273,
#  'right': -1.0647107369924282,
#  'look': -1.0986122886681098,
#  'lord': -1.0986122886681098,
#  'forgive': -1.0986122886681098,
#  'taken': -1.0986122886681098,
#  'body': -1.0986122886681098,
#  'breathe': -1.0986122886681098,
#  'listening': -1.0986122886681098,
#  'hit': -1.0986122886681098,
#  'minute': -1.0986122886681098,
#  'embrace': -1.0986122886681098,
#  'solve': -1.0986122886681098,
#  'quit': -1.0986122886681098,
#  'scars': -1.0986122886681098,
#  'fresh': -1.0986122886681098,
#  'voice': -1.0986122886681098,
#  'like': -1.1210851445201682,
#  'lookin': -1.1786549963416462,
#  'good': -1.2909841813155656,
#  'eyes': -1.2992829841302609,
#  'bad': -1.3217558399823195,
#  'fuck': -1.3862943611198906,
#  'makin': -1.3862943611198906,
#  'lately': -1.3862943611198906,
#  'business': -1.3862943611198906,
#  'far': -1.5040773967762742,
#  'movin': -1.5040773967762742,
#  'til': -1.6094379124341003,
#  'little': -1.6094379124341003,
#  'haters': -1.6094379124341003,
#  'trying': -1.6094379124341003,
#  'running': -1.6094379124341003,
#  'prove': -1.6094379124341003,
#  'girls': -1.7047480922384253,
#  'thinking': -1.7047480922384253,
#  'tryna': -1.7047480922384253,
#  'man': -1.749199854809259,
#  'big': -1.791759469228055,
#  'fingers': -1.791759469228055,
#  'askin': -1.791759469228055,
#  'hard': -1.8718021769015913,
#  'loves': -1.9459101490553135,
#  'mornin': -1.9459101490553135,
#  'goin': -1.9459101490553135,
#  'night': -2.0149030205422647,
#  'slow': -2.0794415416798357,
#  'friday': -2.0794415416798357,
#  'babe': -2.1972245773362196,
#  'kick': -2.3025850929940455,
#  'listen': -2.3978952727983707,
#  'ladies': -2.3978952727983707,
#  'wave': -2.5649493574615367,
#  'okay': -2.639057329615259,
#  'roll': -2.70805020110221,
#  'daddy': -2.70805020110221,
#  'air': -3.295836866004329,
#  'hands': -3.367295829986474}

# %%
artists = list(df['Artist'].unique())

# %%
def compare_sorted_dist(df):
    # backup
    comparison_dicts = []
    # new column in df
    df['comparison_dict'] = None
    
    for artist in artists:
        artist_df = df[df['Artist'] == artist]
        
        artist_compared = {}
        
        sorted_dist = artist_df['sorted_dist'].values[0]
        
        other_artists = [art for art in artists if art != artist]

        for key, value in sorted_dist.items():
            other_val = 0
            for other in other_artists:
                other_artist_dist = df[df['Artist'] == other]['sorted_dist'].values[0]
                other_artist_val = other_artist_dist.get(key, 0)
                other_val += other_artist_val
                
            if other_val == 0:
                comparison = 1000
            else:
                comparison = math.log(value / other_val)

            artist_compared[key] = comparison
            
        comparison_dicts.append(artist_compared)
        df[df['Artist'] == artist]['comparison_dict'] = artist_compared
    return comparison_dicts

# %%
comparison_dicts = compare_sorted_dist(df)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3672333260.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Artist'] == artist]['comparison_dict'] = artist_compared

# %%
len(comparison_dicts)
# Out:
# 40

# %%
df['comparison_dict'] = comparison_dicts

# %%
df
# Out:
#                      Artist  \
# 0                   Aaliyah
# 1                   Beyoncé
# 2            Britney Spears
# 3          Carly Rae Jepsen
# 4                Charli XCX
# 5                  Dua Lipa
# 6                   Madonna
# 7           Michael Jackson
# 8            Olivia Rodrigo
# 9              Taylor Swift
# 10                     2Pac
# 11     A Tribe Called Quest
# 12                   Eminem
# 13                 Ice Cube
# 14                    JAY-Z
# 15               Kanye West
# 16           Kendrick Lamar
# 17                  MF DOOM
# 18                      Nas
# 19               Yasiin Bey
# 20            Black Sabbath
# 21              Deep Purple
# 22             Foo Fighters
# 23                   Fugazi
# 24             Led Zeppelin
# 25                  Nirvana
# 26  Queens of the Stone Age
# 27       The Rolling Stones
# 28              The Strokes
# 29        The White Stripes
# 30                 Al Green
# 31          Aretha Franklin
# 32          Clarence Carter
# 33          Curtis Mayfield
# 34              Marvin Gaye
# 35          Minnie Riperton
# 36              Nina Simone
# 37             Otis Redding
# 38                Sam Cooke
# 39            Stevie Wonder
#
#                                            all_lyrics genre  gender  \
# 0    dirty south can yall really feel me east coas...   pop  female
# 1    ive been drinkin ive been drinkin i get filth...   pop  female
# 2    oh baby baby oh baby baby  oh baby baby how w...   pop  female
# 3    i threw a wish in the well dont ask me ill ne...   pop  female
# 4    i was busy thinkin bout boys boys boys always...   pop  female
# 5    one  talkin in my sleep at night makin myself...   pop  female
# 6    life is a mystery everyone must stand alone i...   pop  female
# 7    she was more like a beauty queen from a movie...   pop    male
# 8    i got my drivers license last week just like ...   pop  female
# 9    i walked through the door with you the air wa...   pop  female
# 10   suckaass i aint got no mothafuckin friends th...  rock    male
# 11    relax yourself girl please settle down relax...  rock    male
# 12   comin at you at supersonic speed jj fad uh su...  rock    male
# 13   damn forgot to do somethin let me see uh oh y...  rock    male
# 14   youd take the clothes off my back and id let ...  rock    male
# 15   well it is a weepin and a moanin and a gnashi...  rock    male
# 16   nobody pray for me it been that day for me wa...  rock    male
# 17   mic check when i was led to you i knew you we...  rock    male
# 18    yeah yeah ayo black—its time word word its t...  rock    male
# 19    buckabuckabuckabuckabuckabucka haha you know...  rock    male
# 20    finished with my woman cause she couldnt hel...   rap    male
# 21    we all came out to montreux on the lake gene...   rap    male
# 22   hello ive waited here for you everlong tonigh...   rap    male
# 23   out here barely see my breath surrounded by j...   rap    male
# 24    theres a lady whos sure all that glitters is...   rap    male
# 25   load up on guns bring your friends its fun to...   rap    male
# 26   we get some rules to follow that and this the...   rap    male
# 27   yeow yeow yeow  please allow me to introduce ...   rap    male
# 28   theyve been sayin youre sophisticated theyre ...   rap    male
# 29   im gonna fight em off a seven nation army cou...   rap    male
# 30   lets stay together  i im so in love with you ...  soul    male
# 31    what you want baby i got it what you need do...  soul  female
# 32  i was born and raised down in alabama on a far...  soul    male
# 33   im your mama im your daddy im that nigga in t...  soul    male
# 34   hey heyhey hey whats happenin hey brother wha...  soul    male
# 35   lovin you is easy cause youre beautiful makin...  soul  female
# 36   birds flying high you know how i feel sun in ...  soul  female
# 37   sittin in the mornin sun ill be sittin when t...  soul    male
# 38   i was born by the river in a little tent oh a...  soul    male
# 39   as around the sun the earth knows shes revolv...  soul    male
#
#                                             freq_dist  \
# 0   {'dirty': 4, 'south': 4, 'feel': 42, 'east': 4...
# 1   {'ve': 19, 'drinkin': 6, 'filthy': 1, 'liquor'...
# 2   {'oh': 103, 'baby': 90, 'supposed': 2, 'know':...
# 3   {'threw': 1, 'wish': 2, 'nt': 104, 'ask': 1, '...
# 4   {'busy': 10, 'thinkin': 9, 'bout': 24, 'boys':...
# 5   {'talkin': 1, 'sleep': 5, 'night': 33, 'makin'...
# 6   {'life': 13, 'mystery': 5, 'stand': 3, 'hear':...
# 7   {'like': 51, 'beauty': 1, 'queen': 1, 'movie':...
# 8   {'got': 23, 'drivers': 1, 'license': 1, 'week'...
# 9   {'walked': 4, 'door': 8, 'air': 3, 'cold': 2, ...
# 10  {'suckaass': 1, 'ai': 104, 'nt': 274, 'got': 1...
# 11  {'relax': 39, 'girl': 42, 'settle': 37, 'honey...
# 12  {'comin': 6, 'supersonic': 1, 'speed': 1, 'jj'...
# 13  {'damn': 9, 'forgot': 6, 'somethin': 1, 'let':...
# 14  {'clothes': 4, 'let': 23, 'yeah': 128, 'steal'...
# 15  {'weepin': 11, 'moanin': 9, 'gnashin': 11, 'te...
# 16  {'pray': 14, 'day': 19, 'way': 44, 'yeah': 40,...
# 17  {'mic': 13, 'check': 8, 'led': 2, 'knew': 5, '...
# 18  {'yeah': 53, 'ayo': 6, 'black': 27, 'time': 37...
# 19  {'buckabuckabuckabuckabuckabucka': 1, 'haha': ...
# 20  {'finished': 1, 'woman': 2, 'cause': 8, 'nt': ...
# 21  {'came': 6, 'montreux': 1, 'lake': 1, 'geneva'...
# 22  {'hello': 1, 've': 23, 'waited': 9, 'everlong'...
# 23  {'barely': 1, 'breath': 1, 'surrounded': 1, 'j...
# 24  {'lady': 4, 'sure': 4, 'glitters': 1, 'gold': ...
# 25  {'load': 1, 'guns': 1, 'bring': 1, 'friends': ...
# 26  {'rules': 1, 'follow': 5, 'knows': 6, 'pills':...
# 27  {'yeow': 3, 'allow': 1, 'introduce': 2, 'man':...
# 28  {'ve': 12, 'sayin': 2, 'sophisticated': 1, 'co...
# 29  {'gon': 40, 'na': 40, 'fight': 3, 'em': 6, 'se...
# 30  {'lets': 7, 'stay': 9, 'love': 107, 'want': 14...
# 31  {'want': 11, 'baby': 76, 'got': 62, 'need': 27...
# 32  {'born': 1, 'raised': 2, 'alabama': 1, 'farm':...
# 33  {'mama': 9, 'daddy': 3, 'nigga': 2, 'alley': 2...
# 34  {'hey': 21, 'heyhey': 1, 'happenin': 3, 'broth...
# 35  {'lovin': 11, 'easy': 2, 'cause': 16, 'beautif...
# 36  {'birds': 1, 'flying': 1, 'high': 2, 'know': 5...
# 37  {'sittin': 7, 'mornin': 2, 'sun': 4, 'ill': 8,...
# 38  {'born': 1, 'river': 8, 'little': 10, 'tent': ...
# 39  {'sun': 9, 'earth': 12, 'knows': 4, 'revolving...
#
#                                           sorted_dist  \
# 0   {'nt': 208, 'let': 113, 'baby': 96, 'know': 89...
# 1   {'nt': 200, 'like': 135, 'love': 119, 'halo': ...
# 2   {'nt': 121, 'oh': 103, 'like': 91, 'baby': 90,...
# 3   {'love': 123, 'nt': 104, 'want': 95, 'gimmie':...
# 4   {'got': 239, 'like': 206, 'party': 166, 'shake...
# 5   {'nt': 232, 'know': 80, 'come': 78, 'got': 69,...
# 6   {'like': 120, 'nt': 116, 'got': 77, 've': 74, ...
# 7   {'nt': 190, 'ma': 174, 'yeah': 139, 'know': 93...
# 8   {'nt': 121, 'like': 71, 'know': 65, 'oh': 59, ...
# 9   {'nt': 107, 'like': 88, 'know': 52, 'cause': 4...
# 10  {'nt': 274, 'ai': 104, 'got': 101, 'know': 79,...
# 11  {'nt': 159, 'like': 116, 'got': 110, 'know': 7...
# 12  {'nt': 309, 'like': 162, 'cause': 102, 'got': ...
# 13  {'nt': 190, 'got': 106, 'fuck': 101, 'like': 1...
# 14  {'nt': 215, 'yeah': 128, 'nigga': 121, 'got': ...
# 15  {'nt': 182, 'got': 106, 'know': 86, 'like': 78...
# 16  {'nt': 178, 'got': 125, 'nigga': 115, 'like': ...
# 17  {'like': 170, 'nt': 91, 'doom': 47, 'got': 46,...
# 18  {'like': 144, 'nt': 141, 'nas': 87, 'love': 84...
# 19  {'nt': 157, 'like': 122, 'got': 101, 'know': 9...
# 20  {'yeah': 35, 'oh': 25, 'like': 25, 'love': 24,...
# 21  {'nt': 45, 'oh': 45, 'got': 41, 'yeah': 39, 'l...
# 22  {'shame': 58, 'nt': 55, 'like': 53, 'best': 42...
# 23  {'like': 36, 'nt': 34, 'got': 34, 've': 33, 's...
# 24  {'oh': 142, 'baby': 70, 'love': 69, 'ah': 67, ...
# 25  {'nt': 86, 'yeah': 61, 'said': 49, 'way': 46, ...
# 26  {'ah': 62, 'nt': 48, 'like': 39, 'oh': 29, 'wa...
# 27  {'nt': 121, 'yeah': 83, 'like': 43, 'hey': 41,...
# 28  {'nt': 134, 'oh': 80, 'yeah': 49, 'like': 48, ...
# 29  {'nt': 71, 'love': 48, 'know': 45, 'gon': 40, ...
# 30  {'love': 107, 'yeah': 95, 'baby': 86, 'nt': 62...
# 31  {'nt': 113, 'oh': 93, 'love': 85, 'chain': 80,...
# 32  {'nt': 111, 'love': 83, 'got': 42, 'baby': 35,...
# 33  {'nt': 110, 'love': 52, 'world': 41, 'got': 40...
# 34  {'baby': 156, 'oh': 113, 'nt': 78, 'love': 76,...
# 35  {'na': 83, 'love': 81, 'la': 78, 'oh': 48, 'ba...
# 36  {'nt': 110, 'got': 63, 'power': 57, 'lord': 55...
# 37  {'love': 88, 'got': 70, 'nt': 66, 'oh': 53, 'v...
# 38  {'know': 85, 'day': 65, 'yeah': 64, 'oh': 53, ...
# 39  {'love': 129, 'nt': 107, 'da': 105, 'la': 68, ...
#
#                                       comparison_dict
# 0   {'nt': -3.128782781341163, 'let': -1.875200073...
# 1   {'nt': -3.169685580677429, 'like': -2.97363813...
# 2   {'nt': -3.6886728211965774, 'oh': -2.708697240...
# 3   {'love': -2.8260138889133617, 'nt': -3.8435794...
# 4   {'got': -2.1457110428861115, 'like': -2.523785...
# 5   {'nt': -3.0145201874196244, 'know': -3.2153696...
# 6   {'like': -3.0970847678142785, 'nt': -3.7319059...
# 7   {'nt': -3.223077511721901, 'ma': 2.96183072187...
# 8   {'nt': -3.6886728211965774, 'like': -3.6401773...
# 9   {'nt': -3.81452351494331, 'like': -3.419215887...
# 10  {'nt': -2.8392065126796706, 'ai': -2.073413795...
# 11  {'nt': -3.4076753063107086, 'like': -3.1324912...
# 12  {'nt': -2.7114962523263513, 'like': -2.7810405...
# 13  {'nt': -3.223077511721901, 'got': -3.021804513...
# 14  {'nt': -3.0942086829163653, 'yeah': -2.6811285...
# 15  {'nt': -3.2677706408089597, 'got': -3.02180451...
# 16  {'nt': -3.290830597726185, 'got': -2.848159909...
# 17  {'like': -2.729773320634529, 'nt': -3.97978434...
# 18  {'like': -2.9056859928692074, 'nt': -3.5315618...
# 19  {'nt': -3.4207501963165163, 'like': -3.0798021...
# 20  {'yeah': -4.026371578635895, 'oh': -4.17377169...
# 21  {'nt': -4.693384542810947, 'oh': -3.5735932986...
# 22  {'shame': 0.8823891801984737, 'nt': -4.4906771...
# 23  {'like': -4.332194260926006, 'nt': -4.97592205...
# 24  {'oh': -2.362049141025235, 'baby': -2.87437141...
# 25  {'nt': -4.037322937931644, 'yeah': -3.45750540...
# 26  {'ah': -1.7336518384207742, 'nt': -4.628235458...
# 27  {'nt': -3.6886728211965774, 'yeah': -3.1381099...
# 28  {'nt': -3.5839334462340657, 'oh': -2.976167118...
# 29  {'nt': -4.2320631855373305, 'love': -3.8024871...
# 30  {'love': -2.9730469907229073, 'yeah': -2.99678...
# 31  {'nt': -3.7587274171330356, 'oh': -2.817274211...
# 32  {'nt': -3.7769975757930183, 'love': -3.2384421...
# 33  {'nt': -3.7862536181391127, 'love': -3.7205830...
# 34  {'baby': -2.0011334398185077, 'oh': -2.6095490...
# 35  {'na': -2.0236995586716007, 'love': -3.2637783...
# 36  {'nt': -3.7862536181391127, 'got': -3.56167719...
# 37  {'love': -3.177580233370114, 'got': -3.4531571...
# 38  {'know': -3.152233130726203, 'day': -1.9146576...
# 39  {'love': -2.7754914818977428, 'nt': -3.8145235...

# %%
df.to_csv('dataframes/freq_dist_comparisons_raw.csv')

# %%
import pickle
with open('comparison_dicts.pickle', 'wb') as handle:
    pickle.dump(comparison_dicts, handle, protocol=pickle.HIGHEST_PROTOCOL)
