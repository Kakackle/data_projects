# %% [markdown]
# ## Visualizations with dash
#
# ### Dynamic multi-input etc
# * https://dash.plotly.com/advanced-callbacks
# * https://community.plotly.com/t/updating-a-dropdown-menus-contents-dynamically/4920/4
# * https://dash-example-index.herokuapp.com/?code=dcc.Dropdown
# * https://dash.plotly.com/dash-core-components/dropdown
# * https://dash-bootstrap-components.opensource.faculty.ai/examples/iris/

# %%
from dash import Dash, html, dcc, callback, Output, Input
import dash_bootstrap_components as dbc
import plotly.express as px
import pandas as pd

# %%
counts_df = pd.read_csv('dataframes/with_counts/combined_count.csv', index_col=0)

# %%
counts_df.head()
# Out:
#     Artist                      Song Title  \
# 0  Aaliyah          Are You That Somebody?
# 1  Aaliyah                     Enough Said
# 2  Aaliyah     At Your Best (You Are Love)
# 3  Aaliyah                        Miss You
# 4  Aaliyah  Age Ain’t Nothing But a Number
#
#                                           Full Title Release Date    Year  \
# 0  Are You That Somebody? by Aaliyah (Ft. Timbaland)   1998-05-26  1998.0
# 1                 Enough Said by Aaliyah (Ft. Drake)   2012-08-05  2012.0
# 2             At Your Best (You Are Love) by Aaliyah   1994-08-22  1994.0
# 3                                Miss You by Aaliyah   2002-11-16  2002.0
# 4          Age Ain't Nothing But a Number by Aaliyah   1994-12-06  1994.0
#
#    Month   Day  Pageviews                                                url  \
# 0    5.0  26.0     373960  https://genius.com/Aaliyah-are-you-that-somebo...
# 1    8.0   5.0     316333      https://genius.com/Aaliyah-enough-said-lyrics
# 2    8.0  22.0     285549  https://genius.com/Aaliyah-at-your-best-you-ar...
# 3   11.0  16.0     245608         https://genius.com/Aaliyah-miss-you-lyrics
# 4   12.0   6.0     207419  https://genius.com/Aaliyah-age-aint-nothing-bu...
#
#    featured_count  ...  VBG  VBN VBP VBZ WDT  WP  WP$  WRB  genre  emotion
# 0               1  ...    5    4  26  14   1   1    1    1    pop  sadness
# 1               1  ...    5    4  26  14   1   1    1    1    pop    anger
# 2               0  ...    5    4  26  14   1   1    1    1    pop  sadness
# 3               0  ...    5    4  26  14   1   1    1    1    pop  sadness
# 4               0  ...    5    4  26  14   1   1    1    1    pop      joy
#
# [5 rows x 73 columns]

# %%
list(counts_df.columns)
# Out:
# ['Artist',
#  'Song Title',
#  'Full Title',
#  'Release Date',
#  'Year',
#  'Month',
#  'Day',
#  'Pageviews',
#  'url',
#  'featured_count',
#  'producer_count',
#  'writer_count',
#  'Song Lyrics',
#  'Artist Image',
#  'gender',
#  'unique_words',
#  'total_words',
#  'manual_love_count',
#  'manual_money_count',
#  'manual_violence_count',
#  'manual_drugs_count',
#  'manual_gendered_count',
#  'manual_sadness_count',
#  'manual_joy_count',
#  'manual_yes_count',
#  'manual_no_count',
#  'manual_love_word_percent',
#  'manual_money_word_percent',
#  'manual_violence_word_percent',
#  'manual_drugs_word_percent',
#  'manual_gendered_word_percent',
#  'manual_sadness_word_percent',
#  'manual_joy_word_percent',
#  'manual_yes_word_percent',
#  'manual_no_word_percent',
#  'sentiment',
#  'CC',
#  'CD',
#  'DT',
#  'EX',
#  'FW',
#  'IN',
#  'JJ',
#  'JJR',
#  'JJS',
#  'LS',
#  'MD',
#  'NN',
#  'NNS',
#  'NNP',
#  'NNPS',
#  'PDT',
#  'POS',
#  'PRP',
#  'PRP$',
#  'RB',
#  'RBR',
#  'RBS',
#  'RP',
#  'TO',
#  'UH',
#  'VB',
#  'VBD',
#  'VBG',
#  'VBN',
#  'VBP',
#  'VBZ',
#  'WDT',
#  'WP',
#  'WP$',
#  'WRB',
#  'genre',
#  'emotion']

# %%
app = Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])

# %%
artists = list(counts_df.Artist.unique())

# %%
topics = [
 'manual_love_count',
 'manual_money_count',
 'manual_violence_count',
 'manual_drugs_count',
 'manual_gendered_count',
 'manual_sadness_count',
 'manual_joy_count',
 'manual_yes_count',
 'manual_no_count'
]

# %%
# df[df['Artist'] == 'Al Green'].Year.unique()

# %%
controls = dbc.Card(
    [
        html.Div(
            [
            dbc.Label("Genre"),
            dcc.Dropdown(
                id='topic-genre-selection',
                value = 'soul',
                options = list(counts_df.genre.unique()),
                multi = True
            )
            ]),
        html.Div(
            [
            dbc.Label("Artist"),
            # dcc.Dropdown(df.Artist.unique(), 'Al Green', id='topic-artist-selection')
            dcc.Dropdown(
                id='topic-artist-selection-dynamic',
                multi = True
            )
            ]),
        html.Div(
            [
            dbc.Label("Manual word topic"),
            dcc.Dropdown(topics, 'manual_love_count', id='topic-selection')
            ]),
        # html.Div(
        #     [
        #     dbc.Label("Year"),
        #     dcc.Dropdown(id='year-selection-dynamic')
        #     ])
    ],
    body=True,
)


app.layout = dbc.Container([
    html.H1(children = 'Genre and Artist manual topic counts by year', style={'textAlign': 'center'}),
    html.P(children="multi artist select result:"),
    html.P(id="multi-artist-dynamic-test"),
    dbc.Row(
        [
            dbc.Col(controls, md=4),
            dbc.Col(dcc.Graph(id='topic-graph-content'), md=8),
        ],
        align="center",
    ),
    # dbc.DropdownMenu(label="Artist", id="artist-selection", children=items),
    # dbc.Select(id="artist-selection", options=items),
    html.Hr(),
], fluid=True)

# %%
@app.callback(
    Output('topic-graph-content', 'figure'),
    Input('topic-genre-selection', 'value'),
    Input('topic-artist-selection-dynamic', 'value'),
    Input('topic-selection', 'value'),
    # Input('year-selection-dynamic', 'value')
)
def update_topic_graph(genres, artists, topic):
    genre_df = counts_df[counts_df['genre'].isin(genres)]
    # in case there is only one artist selected
    print(f'genre_df: {genre_df.shape}')
    artists_list = [artist for artist in artists]
    artists_df = counts_df[genre_df['Artist'].isin(artists_list)]
    print(f'artists_df: {artists_df.shape}')
    # dff = df[df.Artist == artist]
    fig = px.bar(artists_df, x='Year', y=topic, color='genre',
                hover_data = ['Artist'])
    return fig

@app.callback(
    Output('multi-artist-dynamic-test', 'children'),
    Input('topic-artist-selection-dynamic', 'value')
)
def test_multi_dynamic(artists):
    return f'please man {artists}'

@app.callback(
    Output('topic-artist-selection-dynamic', 'options'),
    Input('topic-genre-selection', 'value')
)
def set_dynamic_artist_options(genres):
    options = dict()
    for genre in genres:
        genre_artists = list(counts_df[counts_df['genre'] == genre]['Artist'].unique())
        for artist in genre_artists:
            options[artist] = artist
    return options

@app.callback(
    Output('topic-artist-selection-dynamic', 'value'),
    Input('topic-artist-selection-dynamic', 'options')
)
def set_dynamic_artist_value(options):
    # output = [option for option in options]
    # return output
    return options

# @app.callback(
#     Output('year-selection-dynamic', 'options'),
#     Input('artist-selection', 'value')
# )
# def set_dynamic_year_options(selected_artist):
#     years = list( df[df['Artist'] == selected_artist]['Year'].unique() )
#     return [
#         {'label': year, 'value': year} for year in years
#     ]

# @app.callback(
#     Output('year-selection-dynamic', 'value'),
#     Input('year-selection-dynamic', 'options')
# )
# def set_dynamic_year_value(year_options):
#     return year_options[0]['value']

# %%
app.run()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
counts_df[counts_df['Artist'].isin(['A Tribe Called Quest', 'MF DOOM'])]
# Out:
#                    Artist           Song Title  \
# 220  A Tribe Called Quest  Electric Relaxation
# 221  A Tribe Called Quest    We the People....
# 222  A Tribe Called Quest             Scenario
# 223  A Tribe Called Quest       Can I Kick It?
# 224  A Tribe Called Quest      Check the Rhime
# 225  A Tribe Called Quest          Buggin’ Out
# 226  A Tribe Called Quest      Bonita Applebum
# 227  A Tribe Called Quest     Jazz (We’ve Got)
# 228  A Tribe Called Quest    The Space Program
# 229  A Tribe Called Quest           Award Tour
# 230  A Tribe Called Quest           Excursions
# 231  A Tribe Called Quest         Conrad Tokyo
# 232  A Tribe Called Quest       Dis Generation
# 233  A Tribe Called Quest              Hot Sex
# 234  A Tribe Called Quest           The Donald
# 235  A Tribe Called Quest           Find a Way
# 236  A Tribe Called Quest              Kids...
# 237  A Tribe Called Quest            Oh My God
# 238  A Tribe Called Quest  Solid Wall of Sound
# 239  A Tribe Called Quest               Butter
# 340               MF DOOM             Doomsday
# 341               MF DOOM  Rapp Snitch Knishes
# 342               MF DOOM             Beef Rap
# 343               MF DOOM             One Beer
# 344               MF DOOM            Hoe Cakes
# 345               MF DOOM          That’s That
# 346               MF DOOM    Rhymes Like Dimes
# 347               MF DOOM     Deep Fried Frenz
# 348               MF DOOM           Potholderz
# 349               MF DOOM       Gazzillion Ear
# 350               MF DOOM            Vomitspit
# 351               MF DOOM    ? (Question Mark)
# 352               MF DOOM        All Outta Ale
# 353               MF DOOM            Kon Karne
# 354               MF DOOM              Kookies
# 355               MF DOOM            Kon Queso
# 356               MF DOOM           Gas Drawls
# 357               MF DOOM           Batty Boyz
# 358               MF DOOM           Guinnessez
# 359               MF DOOM         Red and Gold
#
#                                             Full Title Release Date    Year  \
# 220        Electric Relaxation by A Tribe Called Quest   1993-11-09  1993.0
# 221          We the People.... by A Tribe Called Quest   2016-11-11  2016.0
# 222  Scenario by A Tribe Called Quest (Ft. Leaders ...   1991-09-24  1991.0
# 223             Can I Kick It? by A Tribe Called Quest   1990-04-17  1990.0
# 224            Check the Rhime by A Tribe Called Quest   1991-09-24  1991.0
# 225                Buggin' Out by A Tribe Called Quest   1991-09-24  1991.0
# 226            Bonita Applebum by A Tribe Called Quest   1990-02-19  1990.0
# 227           Jazz (We've Got) by A Tribe Called Quest   1991-09-24  1991.0
# 228          The Space Program by A Tribe Called Quest   2016-11-11  2016.0
# 229  Award Tour by A Tribe Called Quest (Ft. Trugoy...   1993-11-09  1993.0
# 230                 Excursions by A Tribe Called Quest   1991-09-24  1991.0
# 231  Conrad Tokyo by A Tribe Called Quest (Ft. Jack...   2016-11-11  2016.0
# 232  Dis Generation by A Tribe Called Quest (Ft. Bu...   2016-11-11  2016.0
# 233                    Hot Sex by A Tribe Called Quest   1992-06-30  1992.0
# 234  The Donald by A Tribe Called Quest (Ft. Busta ...   2016-11-11  2016.0
# 235                 Find a Way by A Tribe Called Quest   1998-08-25  1998.0
# 236   Kids... by A Tribe Called Quest (Ft. André 3000)   2016-11-11  2016.0
# 237  Oh My God by A Tribe Called Quest (Ft. Busta R...   1993-11-09  1993.0
# 238  Solid Wall of Sound by A Tribe Called Quest (F...   2016-11-11  2016.0
# 239                     Butter by A Tribe Called Quest   1991-09-24  1991.0
# 340  Doomsday by MF DOOM (Ft. Pebbles the Invisible...   1999-10-19  1999.0
# 341  Rapp Snitch Knishes by MF DOOM (Ft. Mr. Fantas...   2004-11-16  2004.0
# 342                                Beef Rap by MF DOOM   2003-09-02  2003.0
# 343                                One Beer by MF DOOM   2004-03-30  2004.0
# 344                               Hoe Cakes by MF DOOM   2004-11-09  2004.0
# 345                             That's That by MF DOOM   2009-03-24  2009.0
# 346         Rhymes Like Dimes by MF DOOM (Ft. Bobbito)   1999-10-19  1999.0
# 347                        Deep Fried Frenz by MF DOOM   2004-11-16  2004.0
# 348           Potholderz by MF DOOM (Ft. Count Bass D)   2003-09-02  2003.0
# 349            Gazzillion Ear by MF DOOM (Ft. J Dilla)   2009-03-24  2009.0
# 350                               Vomitspit by MF DOOM   2004-11-16  2004.0
# 351         ? (Question Mark) by MF DOOM (Ft. Kurious)   1999-10-19  1999.0
# 352                           All Outta Ale by MF DOOM   2002-10-01  2002.0
# 353                               Kon Karne by MF DOOM   2004-01-22  2004.0
# 354                                 Kookies by MF DOOM   2004-11-16  2004.0
# 355                               Kon Queso by MF DOOM   2004-01-22  2004.0
# 356                              Gas Drawls by MF DOOM   1999-10-19  1999.0
# 357                              Batty Boyz by MF DOOM   2009-03-24  2009.0
# 358         Guinnessez by MF DOOM (Ft. 4-IZE & StaHHr)   2004-11-16  2004.0
# 359        Red and Gold by MF DOOM (Ft. King Geedorah)   1999-10-19  1999.0
#
#      Month   Day  Pageviews  \
# 220   11.0   9.0     552782
# 221   11.0  11.0     543961
# 222    9.0  24.0     508665
# 223    4.0  17.0     441701
# 224    9.0  24.0     332387
# 225    9.0  24.0     305617
# 226    2.0  19.0     263762
# 227    9.0  24.0     251774
# 228   11.0  11.0     238727
# 229   11.0   9.0     231449
# 230    9.0  24.0     195613
# 231   11.0  11.0     180788
# 232   11.0  11.0     179779
# 233    6.0  30.0     155967
# 234   11.0  11.0     151340
# 235    8.0  25.0     144426
# 236   11.0  11.0     140925
# 237   11.0   9.0     134581
# 238   11.0  11.0     133961
# 239    9.0  24.0     124304
# 340   10.0  19.0     944595
# 341   11.0  16.0     563570
# 342    9.0   2.0     524218
# 343    3.0  30.0     408310
# 344   11.0   9.0     364530
# 345    3.0  24.0     355032
# 346   10.0  19.0     345688
# 347   11.0  16.0     305339
# 348    9.0   2.0     205602
# 349    3.0  24.0     194769
# 350   11.0  16.0     182290
# 351   10.0  19.0     163570
# 352   10.0   1.0     163161
# 353    1.0  22.0     159031
# 354   11.0  16.0     144488
# 355    1.0  22.0     132572
# 356   10.0  19.0     113287
# 357    3.0  24.0     108838
# 358   11.0  16.0     105522
# 359   10.0  19.0      85907
#
#                                                    url  featured_count  ...  \
# 220  https://genius.com/A-tribe-called-quest-electr...               0  ...
# 221  https://genius.com/A-tribe-called-quest-we-the...               0  ...
# 222  https://genius.com/A-tribe-called-quest-scenar...               1  ...
# 223  https://genius.com/A-tribe-called-quest-can-i-...               0  ...
# 224  https://genius.com/A-tribe-called-quest-check-...               0  ...
# 225  https://genius.com/A-tribe-called-quest-buggin...               0  ...
# 226  https://genius.com/A-tribe-called-quest-bonita...               0  ...
# 227  https://genius.com/A-tribe-called-quest-jazz-w...               0  ...
# 228  https://genius.com/A-tribe-called-quest-the-sp...               0  ...
# 229  https://genius.com/A-tribe-called-quest-award-...               1  ...
# 230  https://genius.com/A-tribe-called-quest-excurs...               0  ...
# 231  https://genius.com/A-tribe-called-quest-conrad...               2  ...
# 232  https://genius.com/A-tribe-called-quest-dis-ge...               1  ...
# 233  https://genius.com/A-tribe-called-quest-hot-se...               0  ...
# 234  https://genius.com/A-tribe-called-quest-the-do...               2  ...
# 235  https://genius.com/A-tribe-called-quest-find-a...               0  ...
# 236  https://genius.com/A-tribe-called-quest-kids-l...               1  ...
# 237  https://genius.com/A-tribe-called-quest-oh-my-...               1  ...
# 238  https://genius.com/A-tribe-called-quest-solid-...               3  ...
# 239  https://genius.com/A-tribe-called-quest-butter...               0  ...
# 340         https://genius.com/Mf-doom-doomsday-lyrics               1  ...
# 341  https://genius.com/Mf-doom-rapp-snitch-knishes...               1  ...
# 342         https://genius.com/Mf-doom-beef-rap-lyrics               0  ...
# 343         https://genius.com/Mf-doom-one-beer-lyrics               0  ...
# 344        https://genius.com/Mf-doom-hoe-cakes-lyrics               0  ...
# 345       https://genius.com/Mf-doom-thats-that-lyrics               0  ...
# 346  https://genius.com/Mf-doom-rhymes-like-dimes-l...               1  ...
# 347  https://genius.com/Mf-doom-deep-fried-frenz-ly...               0  ...
# 348       https://genius.com/Mf-doom-potholderz-lyrics               1  ...
# 349   https://genius.com/Mf-doom-gazzillion-ear-lyrics               1  ...
# 350        https://genius.com/Mf-doom-vomitspit-lyrics               0  ...
# 351    https://genius.com/Mf-doom-question-mark-lyrics               1  ...
# 352    https://genius.com/Mf-doom-all-outta-ale-lyrics               0  ...
# 353        https://genius.com/Mf-doom-kon-karne-lyrics               0  ...
# 354          https://genius.com/Mf-doom-kookies-lyrics               0  ...
# 355        https://genius.com/Mf-doom-kon-queso-lyrics               0  ...
# 356       https://genius.com/Mf-doom-gas-drawls-lyrics               0  ...
# 357       https://genius.com/Mf-doom-batty-boyz-lyrics               0  ...
# 358       https://genius.com/Mf-doom-guinnessez-lyrics               2  ...
# 359     https://genius.com/Mf-doom-red-and-gold-lyrics               1  ...
#
#      VBG  VBN VBP VBZ WDT  WP  WP$  WRB  genre  emotion
# 220    5    4  26  14   1   1    1    1   rock      joy
# 221    5    4  26  14   1   1    1    1   rock    anger
# 222    5    4  26  14   1   1    1    1   rock    anger
# 223    5    4  26  14   1   1    1    1   rock      joy
# 224    5    4  26  14   1   1    1    1   rock      joy
# 225    5    4  26  14   1   1    1    1   rock    anger
# 226    5    4  26  14   1   1    1    1   rock      joy
# 227    5    4  26  14   1   1    1    1   rock      joy
# 228    5    4  26  14   1   1    1    1   rock      joy
# 229    5    4  26  14   1   1    1    1   rock      joy
# 230    5    4  26  14   1   1    1    1   rock      joy
# 231    5    4  26  14   1   1    1    1   rock  sadness
# 232    5    4  26  14   1   1    1    1   rock      joy
# 233    5    4  26  14   1   1    1    1   rock      joy
# 234    5    4  26  14   1   1    1    1   rock    anger
# 235    5    4  26  14   1   1    1    1   rock      joy
# 236    5    4  26  14   1   1    1    1   rock  sadness
# 237    5    4  26  14   1   1    1    1   rock    anger
# 238    5    4  26  14   1   1    1    1   rock    anger
# 239    5    4  26  14   1   1    1    1   rock  sadness
# 340    5    4  26  14   1   1    1    1   rock      joy
# 341    5    4  26  14   1   1    1    1   rock      joy
# 342    5    4  26  14   1   1    1    1   rock  sadness
# 343    5    4  26  14   1   1    1    1   rock      joy
# 344    5    4  26  14   1   1    1    1   rock      joy
# 345    5    4  26  14   1   1    1    1   rock  sadness
# 346    5    4  26  14   1   1    1    1   rock      joy
# 347    5    4  26  14   1   1    1    1   rock  sadness
# 348    5    4  26  14   1   1    1    1   rock    anger
# 349    5    4  26  14   1   1    1    1   rock  sadness
# 350    5    4  26  14   1   1    1    1   rock  sadness
# 351    5    4  26  14   1   1    1    1   rock     love
# 352    5    4  26  14   1   1    1    1   rock    anger
# 353    5    4  26  14   1   1    1    1   rock     fear
# 354    5    4  26  14   1   1    1    1   rock  sadness
# 355    5    4  26  14   1   1    1    1   rock  sadness
# 356    5    4  26  14   1   1    1    1   rock     fear
# 357    5    4  26  14   1   1    1    1   rock      joy
# 358    5    4  26  14   1   1    1    1   rock      joy
# 359    5    4  26  14   1   1    1    1   rock      joy
#
# [40 rows x 73 columns]
