# %%
from lyricsgenius import Genius

# %%
token = "b9lZQWs8rZ0Jhcd1rA9MWGmm5cQdvMCWnsdn7LvIjNYf_9tN2qreQmsJnCcOT9ap"

# %%
artist_names = [
    'jay-z',
    'kendrick lamar',
    'mf doom',
    'kanye west',
    'eminem',
    'ghostface killah',
    '2pac',
    'ice cube',
    'nas',
    'black thought'
]

# %%
max_songs = 20
sort_by = 'popularity'
excluded_terms = ["(Remix)", "(Live), (Instrumental)"]

# %%
genius = Genius(token)

# Turn off status messages
genius.verbose = True

# Remove section headers (e.g. [Chorus]) from lyrics when searching
genius.remove_section_headers = True

genius.skip_non_songs = True

# Exclude songs with these words in their title
genius.excluded_terms = excluded_terms

genius.retries = 5

# %%
artist_objects = [genius.search_artist(name, max_songs=max_songs) for name in artist_names]
# Out:
# Searching for songs by jay-z...
#
# Changing artist name to 'JAY-Z'
# Song 1: "Holy Grail"
# Song 2: "Empire State of Mind"
# Song 3: "Part II (On the Run)"
# Song 4: "The Story of O.J."
# Song 5: "4:44"
# Song 6: "Tom Ford"
# Song 7: "FuckWithMeYouKnowIGotIt"
# Song 8: "Renegade"
# Song 9: "99 Problems"
# "Bitch, Don’t Kill My Vibe (Remix)" is not valid. Skipping.
# Song 10: "Oceans"
# Song 11: "Run This Town"
# "Savage Remix" is not valid. Skipping.
# Song 12: "Kill Jay Z"
# Song 13: "Takeover"
# Song 14: "Big Pimpin’"
# Song 15: "Family Feud"
# "Drunk In Love (Remix)" is not valid. Skipping.
# Song 16: "Picasso Baby"
# Song 17: "Public Service Announcement"
# Song 18: "Song Cry"
# Song 19: "Smile"
# "Drunk in Love (Remix)" is not valid. Skipping.
# Song 20: "Open Letter"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by kendrick lamar...
#
# Changing artist name to 'Kendrick Lamar'
# Song 1: "HUMBLE."
# Song 2: "​m.A.A.d city"
# Song 3: "Swimming Pools (Drank)"
# Song 4: "DNA."
# Song 5: "Money Trees"
# Song 6: "XXX."
# Song 7: "Bitch, Don’t Kill My Vibe"
# Song 8: "King Kunta"
# Song 9: "Poetic Justice"
# Song 10: "LOVE."
# Song 11: "Alright"
# Song 12: "Backseat Freestyle"
# Song 13: "Sing About Me, I’m Dying of Thirst"
# Song 14: "The Blacker the Berry"
# Song 15: "ELEMENT."
# Song 16: "LOYALTY."
# Song 17: "​i (Album Version)"
# Song 18: "A.D.H.D"
# Song 19: "FEAR."
# Song 20: "Wesley’s Theory"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by mf doom...
#
# Changing artist name to 'MF DOOM'
# Song 1: "Doomsday"
# Song 2: "Rapp Snitch Knishes"
# Song 3: "Beef Rap"
# Song 4: "One Beer"
# Song 5: "Hoe Cakes"
# Song 6: "That’s That"
# Song 7: "Rhymes Like Dimes"
# Song 8: "Deep Fried Frenz"
# Song 9: "Potholderz"
# Song 10: "Gazzillion Ear"
# Song 11: "Vomitspit"
# Song 12: "? (Question Mark)"
# Song 13: "All Outta Ale"
# Song 14: "Kon Karne"
# Song 15: "Kookies"
# Song 16: "Kon Queso"
# Song 17: "Gas Drawls"
# Song 18: "Batty Boyz"
# Song 19: "Guinnessez"
# Song 20: "Red and Gold"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by kanye west...
#
# Changing artist name to 'Kanye West'
# Song 1: "Mercy"
# Song 2: "Monster"
# Song 3: "Father Stretch My Hands, Pt. 1"
# Song 4: "Ultralight Beam"
# Song 5: "Bound 2"
# Song 6: "New Slaves"
# Song 7: "Runaway"
# Song 8: "Blood On the Leaves"
# Song 9: "Black Skinhead"
# Song 10: "No More Parties in LA"
# Song 11: "Famous"
# Song 12: "POWER"
# Song 13: "All Mine"
# Song 14: "Ghost Town"
# Song 15: "Wolves"
# Song 16: "Gold Digger"
# Song 17: "I Love Kanye"
# Song 18: "Real Friends"
# Song 19: "Off The Grid"
# Song 20: "Can’t Tell Me Nothing"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by eminem...
#
# Changing artist name to 'Eminem'
# Song 1: "Rap God"
# Song 2: "Lose Yourself"
# Song 3: "Killshot"
# Song 4: "Godzilla"
# Song 5: "Without Me"
# Song 6: "The Real Slim Shady"
# Song 7: "Stan"
# Song 8: "The Monster"
# Song 9: "Lucky You"
# Song 10: "The Ringer"
# Song 11: "Mockingbird"
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 artist_objects = [genius.search_artist(name, max_songs=max_songs) for name in artist_names]
#
# Cell In[6], line 1, in <listcomp>(.0)
# ----> 1 artist_objects = [genius.search_artist(name, max_songs=max_songs) for name in artist_names]
#
# File ~\Desktop\programowanie_web_etc\python_projects\data_projects\venv\lib\site-packages\lyricsgenius\genius.py:568, in Genius.search_artist(self, artist_name, max_songs, sort, per_page, get_full_info, allow_name_change, artist_id, include_features)
#     566     lyrics = ""
#     567 if get_full_info:
# --> 568     new_info = self.song(song_info['id'])['song']
#     569     song_info.update(new_info)
#     570 song = Song(self, song_info, lyrics)
#
# File ~\Desktop\programowanie_web_etc\python_projects\data_projects\venv\lib\site-packages\lyricsgenius\api\api.py:437, in API.song(self, song_id, text_format)
#     435 endpoint = "songs/{id}".format(id=song_id)
#     436 params = {'text_format': text_format or self.response_format}
# --> 437 return self._make_request(endpoint, params_=params)
#
# File ~\Desktop\programowanie_web_etc\python_projects\data_projects\venv\lib\site-packages\lyricsgenius\api\base.py:101, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      99     return 204
#     100 else:
# --> 101     raise AssertionError("Response status code was neither 200, nor 204! "
#     102                          "It was {}".format(response.status_code))
#
# AssertionError: Response status code was neither 200, nor 204! It was 503

# %%
artist_objects = []
for name in artist_names:
    try:
        artist_obj = genius.search_artist(name, max_songs=max_songs)
        artist_objects.append(artist_obj)
    except:
        pass
# Out:
# Searching for songs by jay-z...
#
# Changing artist name to 'JAY-Z'
# Song 1: "Holy Grail"
# Song 2: "Empire State of Mind"
# Song 3: "Part II (On the Run)"
# Song 4: "The Story of O.J."
# Song 5: "4:44"
# Song 6: "Tom Ford"
# Song 7: "FuckWithMeYouKnowIGotIt"
# Song 8: "Renegade"
# Song 9: "99 Problems"
# "Bitch, Don’t Kill My Vibe (Remix)" is not valid. Skipping.
# Song 10: "Oceans"
# Song 11: "Run This Town"
# "Savage Remix" is not valid. Skipping.
# Song 12: "Kill Jay Z"
# Song 13: "Takeover"
# Song 14: "Big Pimpin’"
# Song 15: "Family Feud"
# "Drunk In Love (Remix)" is not valid. Skipping.
# Song 16: "Picasso Baby"
# Song 17: "Public Service Announcement"
# Song 18: "Song Cry"
# Song 19: "Smile"
# "Drunk in Love (Remix)" is not valid. Skipping.
# Song 20: "Open Letter"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by kendrick lamar...
#
# Changing artist name to 'Kendrick Lamar'
# Song 1: "HUMBLE."
# Song 2: "​m.A.A.d city"
# Song 3: "Swimming Pools (Drank)"
# Song 4: "DNA."
# Song 5: "Money Trees"
# Song 6: "XXX."
# Song 7: "Bitch, Don’t Kill My Vibe"
# Song 8: "King Kunta"
# Song 9: "Poetic Justice"
# Song 10: "LOVE."
# Song 11: "Alright"
# Song 12: "Backseat Freestyle"
# Song 13: "Sing About Me, I’m Dying of Thirst"
# Song 14: "The Blacker the Berry"
# Song 15: "ELEMENT."
# Song 16: "LOYALTY."
# Song 17: "​i (Album Version)"
# Song 18: "A.D.H.D"
# Song 19: "FEAR."
# Song 20: "Wesley’s Theory"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by mf doom...
#
# Changing artist name to 'MF DOOM'
# Song 1: "Doomsday"
# Song 2: "Rapp Snitch Knishes"
# Song 3: "Beef Rap"
# Song 4: "One Beer"
# Song 5: "Hoe Cakes"
# Song 6: "That’s That"
# Song 7: "Rhymes Like Dimes"
# Song 8: "Deep Fried Frenz"
# Song 9: "Potholderz"
# Song 10: "Gazzillion Ear"
# Song 11: "Vomitspit"
# Song 12: "? (Question Mark)"
# Song 13: "All Outta Ale"
# Song 14: "Kon Karne"
# Song 15: "Kookies"
# Song 16: "Kon Queso"
# Song 17: "Gas Drawls"
# Song 18: "Batty Boyz"
# Song 19: "Guinnessez"
# Song 20: "Red and Gold"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by kanye west...
#
# Changing artist name to 'Kanye West'
# Song 1: "Mercy"
# Song 2: "Monster"
# Song 3: "Father Stretch My Hands, Pt. 1"
# Song 4: "Ultralight Beam"
# Song 5: "Bound 2"
# Song 6: "New Slaves"
# Song 7: "Runaway"
# Song 8: "Blood On the Leaves"
# Song 9: "Black Skinhead"
# Song 10: "No More Parties in LA"
# Song 11: "Famous"
# Song 12: "POWER"
# Song 13: "All Mine"
# Song 14: "Ghost Town"
# Song 15: "Wolves"
# Song 16: "Gold Digger"
# Song 17: "I Love Kanye"
# Song 18: "Real Friends"
# Song 19: "Off The Grid"
# Song 20: "Can’t Tell Me Nothing"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by eminem...
#
# Changing artist name to 'Eminem'
# Song 1: "Rap God"
# Song 2: "Lose Yourself"
# Song 3: "Killshot"
# Song 4: "Godzilla"
# Song 5: "Without Me"
# Song 6: "The Real Slim Shady"
# Song 7: "Stan"
# Song 8: "The Monster"
# Song 9: "Lucky You"
# Song 10: "The Ringer"
# Song 11: "Mockingbird"
# Song 12: "Venom"
# Song 13: "’Till I Collapse"
# Song 14: "River"
# Song 15: "Superman"
# Song 16: "Not Alike"
# Song 17: "Berzerk"
# Song 18: "Fall"
# Song 19: "8 Mile: B-Rabbit vs Papa Doc"
# Song 20: "Love the Way You Lie"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by ghostface killah...
#
# Changing artist name to 'Ghostface Killah'
# Searching for songs by 2pac...
#
# Changing artist name to '2Pac'
# Song 1: "Hit ’Em Up"
# Song 2: "Changes"
# Song 3: "Keep Ya Head Up"
# Song 4: "Hail Mary"
# Song 5: "Dear Mama"
# Song 6: "California Love"
# Song 7: "Ambitionz Az a Ridah"
# Song 8: "All Eyez On Me"
# Song 9: "2 Of Amerikaz Most Wanted"
# Song 10: "Life Goes On"
# Song 11: "The Rose That Grew From Concrete"
# Song 12: "I Ain’t Mad At Cha"
# Song 13: "Only God Can Judge Me"
# Song 14: "Runnin’ (Dying to Live)"
# Song 15: "Me Against the World"
# Song 16: "Do For Love"
# Song 17: "Can’t C Me"
# Song 18: "All About U"
# Song 19: "I Get Around"
# Song 20: "So Many Tears"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by ice cube...
#
# Changing artist name to 'Ice Cube'
# Song 1: "No Vaseline"
# Song 2: "It Was a Good Day"
# "Boyz-N-The Hood (Remix)" is not valid. Skipping.
# Song 3: "Gangsta Rap Made Me Do It"
# Song 4: "Check Yo Self"
# Song 5: "You Know How We Do It"
# Song 6: "Hello"
# Song 7: "The Nigga Ya Love To Hate"
# "Check Yo Self (Remix)" is not valid. Skipping.
# Song 8: "You Can Do It"
# Song 9: "Why We Thugs"
# Song 10: "Good Cop Bad Cop"
# Song 11: "Arrest The President"
# Song 12: "Go To Church"
# Song 13: "Nobody Wants to Die"
# Song 14: "Hood Mentality"
# "8 Ball (Remix)" is not valid. Skipping.
# Song 15: "Black Korea"
# Song 16: "Smoke Some Weed"
# "Dopeman (Remix)" is not valid. Skipping.
# Song 17: "Friday"
# Song 18: "Steady Mobbin’"
# Song 19: "Ghetto Vet"
# Song 20: "AmeriKKKa’s Most Wanted"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by nas...
#
# Changing artist name to 'Nas'
# Song 1: "N.Y. State of Mind"
# Song 2: "Ether"
# Song 3: "Life’s a Bitch"
# Song 4: "The World Is Yours"
# Song 5: "The Message"
# Song 6: "It Ain’t Hard to Tell"
# Song 7: "One Love"
# Song 8: "If I Ruled the World (Imagine That)"
# Song 9: "Represent"
# Song 10: "Nas Is Like"
# Song 11: "Halftime"
# Song 12: "Memory Lane (Sittin’ In Da Park)"
# Song 13: "Affirmative Action"
# Song 14: "One Mic"
# Song 15: "I Can"
# Song 16: "Daughters"
# Song 17: "Cherry Wine"
# "Made Nas Proud [Let Nas Down Remix]" is not valid. Skipping.
# Song 18: "Hate Me Now"
# Song 19: "EPMD 2"
# Song 20: "The Don"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by black thought...
#
# Changing artist name to 'Black Thought'

# %%
genius.save_artists(artist_objects, overwrite=True)
# Out:
# tmp_lyrics\tmp_0_JAY-Z
# Wrote Lyrics_JAYZ.json.
# tmp_lyrics\tmp_1_KendrickLamar
# Wrote Lyrics_KendrickLamar.json.
# tmp_lyrics\tmp_2_MFDOOM
# Wrote Lyrics_MFDOOM.json.
# tmp_lyrics\tmp_3_KanyeWest
# Wrote Lyrics_KanyeWest.json.
# tmp_lyrics\tmp_4_Eminem
# Wrote Lyrics_Eminem.json.
# tmp_lyrics\tmp_5_2Pac
# Wrote Lyrics_2Pac.json.
# tmp_lyrics\tmp_6_IceCube
# Wrote Lyrics_IceCube.json.
# tmp_lyrics\tmp_7_Nas
# Wrote Lyrics_Nas.json.
# Time elapsed: 0.0001534300380282932 hours
